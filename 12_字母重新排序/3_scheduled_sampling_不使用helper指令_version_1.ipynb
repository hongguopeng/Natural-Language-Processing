# %% [markdown]
# # Seq2Seq
# 實現基礎版的Seq2Seq，輸入一個英文單字，模型將輸出一個對字母排序後的單字
# <br>輸入 : hello
# <br>輸出 : ehllo

# %% [markdown]
# 本程式試著不使用Tensorflow所提供的Helper指令，完成Scheduled Sampling<br>
# Scheduled Sampling是一種解決訓練和生成時輸入數據分布不一致的方法<br>
#
# 在一般的Seq2Seq模型的inference階段中，如果Sequence中在t時刻中產生錯誤的值，在t時刻之後的輸入狀態將會受到影響，而該誤差會隨著生成過程不斷向後累積；而Scheduled Sampling以一定概率將Decoder自己產生的值作為Decoder端的輸入，這樣即使前面產生錯誤的值，其目標仍然是最大化真實目標序列的概率，模型會朝著正確的方向進<br>
#
# 在訓練早期Scheduled Sampling主要使用target中的真實值作為Decoder端的輸入，可以將模型從隨機初始化的狀態快速引導至一個合理的狀態；隨著訓練的進行，該方法會逐漸更多地使用Decoder自己產生的值作為Decoder端的輸入，以解決數據分布不一致的問題<br>

# %% [markdown]
# <img src="3_scheduled_sampling_不使用helper指令_version_1.jpg" style="width:1140px;height:600px;float:middle">
#
# 以上為Decoder端的計算流程<br>
# 當前時刻decoder_cell會直接吃mlstm_cell_output(上一個時刻decoder_cell的輸出)<br>

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import time
import copy
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# %% [markdown]
# # 讀取數據

# %%
f = open('data/letters_source.txt', 'r', encoding = 'utf-8')
source_data = f.read()

f = open('data/letters_target.txt', 'r', encoding = 'utf-8')
target_data = f.read()

# %% [markdown]
# # 數據預處理

# %%
def extract_character_vocab(data):
    
    special_words = ['<PAD>' , '<UNK>' , '<GO>' , '<EOS>']
    
    words = []
    for line in data.split('\n'):
        for character in line:
            if character not in words:
                words.append(character)

    # 將四個特殊字加入詞庫       
    int_to_vocab = {idx: word for idx , word in enumerate(special_words + words)}
    vocab_to_int = dict(zip(int_to_vocab.values() , int_to_vocab.keys()))

    return int_to_vocab, vocab_to_int

# %%
source_int_to_letter , source_letter_to_int = extract_character_vocab(source_data)
target_int_to_letter , target_letter_to_int = extract_character_vocab(target_data)

# 將所有字母轉換成index
source_int = []
for line in source_data.split('\n'):
    temp = []
    for letter in line:
        temp.append(source_letter_to_int[letter])
    source_int.append(temp)    
        
target_int = []
for line in target_data.split('\n'):
    temp = []
    for letter in line:
        temp.append(target_letter_to_int[letter])
    temp = temp + [target_letter_to_int['<EOS>']]
    target_int.append(temp)

# %%
# 決定source_int與target_int中的最大長度
# 因為後面的decoder的rnn不是使用tf.nn.dynamic_rnn，無法使用動態長度的功能，所以在這裡就要決定每個batch的長度
source_max_length , target_max_length = 0 , 0  
for vob_source , vob_target in zip(source_int , target_int):
    if len(vob_source) > source_max_length:
        source_max_length = len(vob_source)    
    if len(vob_target) > target_max_length:
        target_max_length = len(vob_target)  

# 分別對source_int與target_int_pad 補source_letter_to_int['<PAD>']與target_letter_to_int['<PAD>']到最大長度  
source_int_pad , target_int_pad = [] , []
for i_source , j_target in zip(range(len(source_int)) , range(len(target_int))):
    temp_source = source_int[i_source].copy()
    while len(temp_source) < source_max_length:
        temp_source.append(source_letter_to_int['<PAD>']) 
    source_int_pad.append(temp_source)
    
    temp_target = target_int[j_target].copy()
    while len(temp_target) < target_max_length:
        temp_target.append(target_letter_to_int['<PAD>']) 
    target_int_pad.append(temp_target)       

source_int_pad = np.array(source_int_pad)
target_int_pad = np.array(target_int_pad)

# %%
# 超參數
# Number of Epochs
epochs = 200
# Batch Size
batch_size = 128
# RNN Size
rnn_hidden_unit = 50
# Number of Layers
num_layers = 1
# Embedding Size
encoding_embedding_size = 15
decoding_embedding_size = rnn_hidden_unit
# Learning Rate
learning_rate = 0.001
source_vocab_size = len(source_int_to_letter)
target_vocab_size = len(target_int_to_letter)

# %% [markdown]
# # Build Model

# %% [markdown]
# ## 輸入層

# %%
input_data = tf.placeholder(tf.int32, [None , source_max_length] , name = 'inputs')
targets = tf.placeholder(tf.int32, [None , target_max_length] , name = 'targets')
targets_onehot = tf.one_hot(tf.reshape(targets , [-1]) , depth = target_vocab_size)
lr = tf.placeholder(tf.float32 , name = 'learning_rate')

# 決定到底是"t-1階段的輸出"還是"target中的真實答案"，當作t階段的輸入
from_model_or_target = tf.placeholder(tf.bool , [target_max_length , ] , name = 'on_train')

# %% [markdown]
# ## Encoder

# %% [markdown]
# 需要對source數據進行embedding，再傳入Decoder中的RNN

# %%
# input_data: 輸入tensor
# rnn_hidden_unit: rnn隱層結點數量
# num_layers: rnn cell的層數
# source_sequence_length: source數據的序列長度
# source_vocab_size: source數據的詞庫大小
# encoding_embedding_size: embedding的向量維度

# Encoder embedding
'''
encoder_embed_input = tf.contrib.layers.embed_sequence(input_data , source_vocab_size , encoding_embedding_size) 
                                                  ⇕ 相當於
encoder_embeddings = tf.Variable(tf.random_uniform([source_vocab_size , encoding_embedding_size]))
encoder_embed_input = tf.nn.embedding_lookup(encoder_embeddings , input_data)

若懶得寫兩行程式可以直接用tf.contrib.layers.embed_sequence這個函數
介紹 : https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence
'''
encoder_embeddings = tf.Variable(tf.random_uniform([source_vocab_size , encoding_embedding_size]))
encoder_embed_input = tf.nn.embedding_lookup(encoder_embeddings , input_data)

def get_lstm_cell(rnn_hidden_unit):
    lstm_cell = tf.contrib.rnn.LSTMCell(rnn_hidden_unit, 
                                        initializer = tf.random_uniform_initializer(-0.1 , 0.1))
    return lstm_cell

with tf.variable_scope('encoder'):   
    encoder_cell = tf.contrib.rnn.MultiRNNCell([get_lstm_cell(rnn_hidden_unit) for _ in range(num_layers)])
    
    encoder_output, encoder_state = tf.nn.dynamic_rnn(encoder_cell , 
                                                      encoder_embed_input, 
                                                      dtype = tf.float32)

# %% [markdown]
# ## Decoder

# %%
# 預處理後的decoder輸入
# 在batch中每一筆data最前面加上<GO>，並移除最後一個字，所以每一筆data的詞的數目並無改變

# cut掉最後一個字
# ending = tf.strided_slice(targets , [0, 0] , [batch_size, -1] , [1, 1]) # 等同於 ending = tf.identity(targets[: , 0:-1])
ending = tf.identity(targets[: , 0:-1])
decoder_input = tf.concat([tf.fill([batch_size, 1] , target_letter_to_int['<GO>']) , ending] , axis = 1)

# %%
# decoding_embedding_size: embedding的向量維度
# num_layers: rnn cell的層數
# rnn_size: RNN單元的隱層結點數量
# encoder_state: encoder端編碼的狀態向量
# decoder_input: decoder端輸入

# 1. Embedding
decoder_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
decoder_embed_input = tf.nn.embedding_lookup(decoder_embeddings , decoder_input)

with tf.variable_scope('decoder'):
    # 2. 建造Decoder中的RNN單元
    decoder_cell = tf.contrib.rnn.MultiRNNCell([get_lstm_cell(rnn_hidden_unit) for _ in range(num_layers)])
    state = encoder_state 
    outputs  = []
    for time_step in range(0 , target_max_length):
        if time_step > 0: tf.get_variable_scope().reuse_variables()  
        
        # 在訓練的過程中，除了time_step為0以外，每一個time_step都投擲硬幣決定
        # 要用decoder_embed_input[: , time_step , :](target中的真實答案)，還是mlstm_cell_output(machine自己產生的output)，輸入decoder_cell
        # 正面代表當前時刻decoder_cell要吃decoder_embed_input[: , time_step , :](target中的真實答案)
        # 反面代表當前時刻decoder_cell要吃mlstm_cell_output(上一個時刻decoder_cell的輸出)
        # 也就是coin tossing為[True , True , True , True , True , True , True , True]會逐漸變為[Faslse , Faslse , Faslse , Faslse , Faslse , Faslse , Faslse , Faslse]
        # 前幾個epoch會有很大的機率擲出正面，但隨著訓練的過程擲出反面的機率會越來越大
        # 在後面的步驟會調節擲出正反面的機率
        if time_step == 0: 
            input_to_decoder = decoder_embed_input[: , 0 , :]
            mlstm_cell_output , state = decoder_cell(input_to_decoder , state)
                
        elif time_step > 0: 
            input_to_decoder = tf.cond(from_model_or_target[time_step] , 
                                       lambda: decoder_embed_input[: , time_step , :] , 
                                       lambda: mlstm_cell_output)
            mlstm_cell_output , state = decoder_cell(input_to_decoder , state)
        
        outputs.append(mlstm_cell_output)

# %%
outputs_ = tf.transpose(tf.convert_to_tensor(outputs) , [1 , 0 , 2])    
outputs_ = tf.reshape(outputs_ , [-1 , rnn_hidden_unit]) 

weights = tf.Variable(tf.truncated_normal([rnn_hidden_unit , target_vocab_size] , mean = 0.01 , stddev = 0.1))
biases = tf.Variable(tf.zeros([1 , target_vocab_size]) + 0.0001)
logits = tf.matmul(outputs_ , weights) + biases 

# predicting_logits與訓練無關，純粹只是要看結果
predicting_logits = tf.nn.softmax(logits)   
predicting_logits = tf.argmax(predicting_logits , axis = 1)
predicting_logits = tf.reshape(predicting_logits , [batch_size , -1] , name = 'predictions')

# %%
# Loss function
loss = tf.nn.softmax_cross_entropy_with_logits(labels = targets_onehot , logits = logits)
total_loss = tf.reduce_mean(loss)

# Optimizer
optimizer = tf.train.AdamOptimizer(lr)

# Gradient Clipping
gradients = optimizer.compute_gradients(total_loss)
capped_gradients = [(tf.clip_by_value(grad, -5. , 5.), var) for grad, var in gradients if grad is not None]
train_op = optimizer.apply_gradients(capped_gradients)
# Out:
# WARNING:tensorflow:From <ipython-input-12-0dda0281734f>:2: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %%
# 將數據集分割為train和validation
train_source = source_int_pad[batch_size:]
train_target = target_int_pad[batch_size:]
# 留出一個batch進行驗證
valid_source = source_int_pad[:batch_size]
valid_target = target_int_pad[:batch_size]

# %% [markdown]
# ## Training

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

prob = 1e-3
alpha = 1.075
stop_early = 0
for epoch_i in range(0 , epochs):
    
    # 在每進行一個epoch前，把每個batch的index先決定出來
    batch_index = []
    temp = []
    count = 0 # 隨機決定index的開頭 
    while len(batch_index) <= 77:  # 1個batch裡只有77筆資料
        temp.append(count)
        count += 1
        if len(temp) == batch_size:
            batch_index.append(temp)
            temp = []
        if count == len(train_source):
            count = 0
    
    # 一開始會出現[True , True , True , True , True , True , True , True]
    # 隨著epoch的增長，逐漸開始出現[Faslse , Faslse , Faslse , Faslse , Faslse , Faslse , Faslse , Faslse]
    # 在Decoder端的訓練，一開始t階段的輸入為t-1階段的期望輸出(Teacher Forcing)，到最後逐漸變為t階段的輸入為t-1階段的輸出(Sampling)
    coin_tossing = np.random.choice(a = 2 , 
                                    size = target_max_length , 
                                    replace = True , 
                                    p = [prob , 1 - prob])
    coin_tossing = coin_tossing.astype(bool)
    if alpha * prob < 1  : prob = alpha * prob # p會隨著epoch增加越來越大
    elif alpha * prob > 1: prob = 1.        

    for batch_i in range(0 , 77):
        train_source_batch , train_target_batch =\
        train_source[batch_index[batch_i] , :] , train_target[batch_index[batch_i] , :] 
        
        _ , training_loss , predicting_logits_result =\
        sess.run([train_op, total_loss , predicting_logits] , 
                 feed_dict = {input_data : train_source_batch ,
                              targets : train_target_batch ,
                              from_model_or_target : coin_tossing ,
                              lr: learning_rate})
   
        if batch_i % 30 == 0: # 每隔30個輪查看一下結果
            validation_loss = sess.run(total_loss, 
                                       feed_dict = {input_data : valid_source ,
                                                    targets : valid_target ,
                                                    from_model_or_target : coin_tossing}) 

            print('Epoch : {}/{} \nBatch : {}/{} \nTraining Loss : {:.3f} \nValidation loss: {:.3f} \nstop_early : {} \ncoin_tossing : {}'
                  .format(epoch_i , epochs , 
                          batch_i , len(train_source) // batch_size , 
                          training_loss , validation_loss , 
                          stop_early , coin_tossing))
            
            index = np.random.randint(batch_size)
            print('Source : {}'.format([source_int_to_letter[i] for i in train_source_batch[index]] ))
            print('Target : {}'.format([target_int_to_letter[i] for i in train_target_batch[index]] ))
            print('Predict : {}\n'.format([target_int_to_letter[i] for i in predicting_logits_result[index]] ))
        
    if coin_tossing.sum() == 0:
        stop_early += 1

    if stop_early == 20: # 當coin_tossing全部為False的次數為20時即停止計算
        break        
    
    
# 保存模型
saver = tf.train.Saver()
saver.save(sess , 'trained_model/save_net')
print('Model Trained and Saved')
# Out:
# Epoch : 0/200
# Batch : 0/77
# Training Loss : 3.419
# Validation loss: 3.372
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['q', 's', 'f', 'l', 'i', '<PAD>', '<PAD>']
# Target : ['f', 'i', 'l', 'q', 's', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['a', 'a', 'a', 'o', 'a', 'a', 'a', 'a']
#
# Epoch : 0/200
# Batch : 30/77
# Training Loss : 2.379
# Validation loss: 2.349
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['l', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['l', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 0/200
# Batch : 60/77
# Training Loss : 1.962
# Validation loss: 1.990
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['t', 'w', 'm', 'a', 'm', 'j', '<PAD>']
# Target : ['a', 'j', 'm', 'm', 't', 'w', '<EOS>', '<PAD>']
# Predict : ['a', 'b', 'd', '<EOS>', '<EOS>', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 1/200
# Batch : 0/77
# Training Loss : 1.933
# Validation loss: 1.824
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['k', 'o', 'l', 't', 'm', '<PAD>', '<PAD>']
# Target : ['k', 'l', 'm', 'o', 't', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['a', 'b', '<EOS>', '<EOS>', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 1/200
# Batch : 30/77
# Training Loss : 1.674
# Validation loss: 1.659
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['j', 'm', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['j', 'm', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['h', '<EOS>', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 1/200
# Batch : 60/77
# Training Loss : 1.508
# Validation loss: 1.538
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['j', 'd', 't', 'i', 's', 'w', 'n']
# Target : ['d', 'i', 'j', 'n', 's', 't', 'w', '<EOS>']
# Predict : ['b', 'b', 'c', 'p', 'p', 'v', '<EOS>', '<EOS>']
#
# Epoch : 2/200
# Batch : 0/77
# Training Loss : 1.581
# Validation loss: 1.490
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['e', 'z', 'z', 'u', 'z', '<PAD>', '<PAD>']
# Target : ['e', 'u', 'z', 'z', 'z', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['a', 'c', 'q', 'w', '<EOS>', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 2/200
# Batch : 30/77
# Training Loss : 1.447
# Validation loss: 1.427
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['k', 'm', 'm', 'h', 'd', 'l', 'b']
# Target : ['b', 'd', 'h', 'k', 'l', 'm', 'm', '<EOS>']
# Predict : ['b', 'b', 'j', 'k', 'p', 'r', 'y', '<EOS>']
#
# Epoch : 2/200
# Batch : 60/77
# Training Loss : 1.357
# Validation loss: 1.380
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['l', 'n', 'l', 'x', 'b', 'a', '<PAD>']
# Target : ['a', 'b', 'l', 'l', 'n', 'x', '<EOS>', '<PAD>']
# Predict : ['b', 'b', 'i', 'p', 'u', 'v', '<EOS>', '<PAD>']
#
# Epoch : 3/200
# Batch : 0/77
# Training Loss : 1.444
# Validation loss: 1.360
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['r', 'j', 'q', 't', 'r', 'j', 'b']
# Target : ['b', 'j', 'j', 'q', 'r', 'r', 't', '<EOS>']
# Predict : ['a', 'c', 'j', 'o', 'q', 't', 'w', '<EOS>']
#
# Epoch : 3/200
# Batch : 30/77
# Training Loss : 1.331
# Validation loss: 1.314
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['a', 'w', 'q', 'i', 'h', 'f', '<PAD>']
# Target : ['a', 'f', 'h', 'i', 'q', 'w', '<EOS>', '<PAD>']
# Predict : ['b', 'b', 'j', 'l', 'r', 'y', '<EOS>', '<PAD>']
#
# Epoch : 3/200
# Batch : 60/77
# Training Loss : 1.223
# Validation loss: 1.243
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['b', 'h', 'g', 'k', '<PAD>', '<PAD>', '<PAD>']
# Target : ['b', 'g', 'h', 'k', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['b', 'b', 'j', 'r', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 4/200
# Batch : 0/77
# Training Loss : 1.288
# Validation loss: 1.207
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['l', 'a', 'a', 'f', 'f', 'u', 'g']
# Target : ['a', 'a', 'f', 'f', 'g', 'l', 'u', '<EOS>']
# Predict : ['a', 'b', 'c', 'j', 'l', 'n', 't', '<EOS>']
#
# Epoch : 4/200
# Batch : 30/77
# Training Loss : 1.163
# Validation loss: 1.142
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['h', 'g', 'z', 'y', 'c', 's', '<PAD>']
# Target : ['c', 'g', 'h', 's', 'y', 'z', '<EOS>', '<PAD>']
# Predict : ['a', 'i', 'j', 'l', 'u', '<EOS>', '<EOS>', '<PAD>']
#
# Epoch : 4/200
# Batch : 60/77
# Training Loss : 1.038
# Validation loss: 1.066
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['x', 'z', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['x', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['t', '<EOS>', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 5/200
# Batch : 0/77
# Training Loss : 1.096
# Validation loss: 1.036
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['s', 'n', 's', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['n', 's', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['n', 'p', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 5/200
# Batch : 30/77
# Training Loss : 0.998
# Validation loss: 0.984
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['o', 'j', 'z', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['j', 'o', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['j', 'l', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 5/200
# Batch : 60/77
# Training Loss : 0.899
# Validation loss: 0.934
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['x', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 6/200
# Batch : 0/77
# Training Loss : 0.965
# Validation loss: 0.905
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['d', 'a', 'v', 'o', 'k', 'o', 'c']
# Target : ['a', 'c', 'd', 'k', 'o', 'o', 'v', '<EOS>']
# Predict : ['a', 'd', 'd', 'n', 'o', 'o', 'v', '<EOS>']
#
# Epoch : 6/200
# Batch : 30/77
# Training Loss : 0.870
# Validation loss: 0.861
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['e', 'p', 's', 'g', 'q', 'v', '<PAD>']
# Target : ['e', 'g', 'p', 'q', 's', 'v', '<EOS>', '<PAD>']
# Predict : ['d', 'g', 'p', 'p', 'v', 'v', '<EOS>', '<PAD>']
#
# Epoch : 6/200
# Batch : 60/77
# Training Loss : 0.778
# Validation loss: 0.818
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['b', 'z', 'e', 'p', 'j', 'v', '<PAD>']
# Target : ['b', 'e', 'j', 'p', 'v', 'z', '<EOS>', '<PAD>']
# Predict : ['b', 'b', 'g', 'q', 'u', 'z', '<EOS>', '<PAD>']
#
# Epoch : 7/200
# Batch : 0/77
# Training Loss : 0.855
# Validation loss: 0.805
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['e', 'z', 'x', 'r', '<PAD>', '<PAD>', '<PAD>']
# Target : ['e', 'r', 'x', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['e', 'r', 'w', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 7/200
# Batch : 30/77
# Training Loss : 0.767
# Validation loss: 0.762
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['z', 'a', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['a', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['d', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 7/200
# Batch : 60/77
# Training Loss : 0.693
# Validation loss: 0.729
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['y', 'v', 'b', 'z', '<PAD>', '<PAD>', '<PAD>']
# Target : ['b', 'v', 'y', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['d', 'u', 'y', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Epoch : 8/200
# Batch : 0/77
# Training Loss : 0.768
# Validation loss: 0.718
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['p', 'h', 'w', 'y', 'c', 'r', 'c']
# Target : ['c', 'c', 'h', 'p', 'r', 'w', 'y', '<EOS>']
# Predict : ['e', 'g', 'h', 'q', 'r', 'w', 'z', '<EOS>']
#
# Epoch : 8/200
# Batch : 30/77
# Training Loss : 0.682
# Validation loss: 0.680
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['b', 'k', 'i', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['b', 'i', 'k', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['b', 'i', 'k', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 8/200
# Batch : 60/77
# Training Loss : 0.618
# Validation loss: 0.655
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['r', 'y', 'i', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['i', 'r', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['i', 'r', '<EOS>', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 9/200
# Batch : 0/77
# Training Loss : 0.685
# Validation loss: 0.633
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['s', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['s', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['s', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 9/200
# Batch : 30/77
# Training Loss : 0.602
# Validation loss: 0.604
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['m', 'q', 'm', 'w', 'u', 'l', '<PAD>']
# Target : ['l', 'm', 'm', 'q', 'u', 'w', '<EOS>', '<PAD>']
# Predict : ['k', 'k', 'm', 'q', 'u', 'x', '<EOS>', '<PAD>']
#
# Epoch : 9/200
# Batch : 60/77
# Training Loss : 0.544
# Validation loss: 0.582
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['y', 's', 'f', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 's', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 's', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 10/200
# Batch : 0/77
# Training Loss : 0.610
# Validation loss: 0.563
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['p', 'h', 'w', 'y', 'c', 'r', 'c']
# Target : ['c', 'c', 'h', 'p', 'r', 'w', 'y', '<EOS>']
# Predict : ['e', 'h', 'h', 'q', 't', 'w', 'y', '<EOS>']
#
# Epoch : 10/200
# Batch : 30/77
# Training Loss : 0.532
# Validation loss: 0.537
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['v', 'p', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['p', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['p', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 10/200
# Batch : 60/77
# Training Loss : 0.480
# Validation loss: 0.517
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['q', 'h', 'j', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['h', 'j', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['h', 'j', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 11/200
# Batch : 0/77
# Training Loss : 0.537
# Validation loss: 0.502
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['s', 'b', 'g', 'e', 'e', 'f', 'f']
# Target : ['b', 'e', 'e', 'f', 'f', 'g', 's', '<EOS>']
# Predict : ['b', 'b', 'e', 'f', 'g', 'l', 's', '<EOS>']
#
# Epoch : 11/200
# Batch : 30/77
# Training Loss : 0.473
# Validation loss: 0.475
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['o', 'k', 'y', 'p', '<PAD>', '<PAD>', '<PAD>']
# Target : ['k', 'o', 'p', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['k', 'n', 'p', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 11/200
# Batch : 60/77
# Training Loss : 0.426
# Validation loss: 0.462
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['x', 'o', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['o', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['o', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 12/200
# Batch : 0/77
# Training Loss : 0.478
# Validation loss: 0.449
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['n', 'q', 'o', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['n', 'o', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['n', 'o', 'u', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 12/200
# Batch : 30/77
# Training Loss : 0.426
# Validation loss: 0.423
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['w', 'y', 'u', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['u', 'w', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['u', 'w', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 12/200
# Batch : 60/77
# Training Loss : 0.381
# Validation loss: 0.417
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['j', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['j', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['j', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 13/200
# Batch : 0/77
# Training Loss : 0.430
# Validation loss: 0.402
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['o', 'p', 'i', 'v', 'v', 'i', '<PAD>']
# Target : ['i', 'i', 'o', 'p', 'v', 'v', '<EOS>', '<PAD>']
# Predict : ['c', 'i', 'o', 'p', 'v', 'v', '<EOS>', '<PAD>']
#
# Epoch : 13/200
# Batch : 30/77
# Training Loss : 0.385
# Validation loss: 0.381
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['l', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['l', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['l', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 13/200
# Batch : 60/77
# Training Loss : 0.341
# Validation loss: 0.381
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['z', 'e', 'k', 'h', 'u', 'z', 'b']
# Target : ['b', 'e', 'h', 'k', 'u', 'z', 'z', '<EOS>']
# Predict : ['b', 'e', 'j', 'k', 'u', 'z', 'z', '<EOS>']
#
# Epoch : 14/200
# Batch : 0/77
# Training Loss : 0.384
# Validation loss: 0.364
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['s', 'n', 's', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['n', 's', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['n', 's', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 14/200
# Batch : 30/77
# Training Loss : 0.351
# Validation loss: 0.343
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['o', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['o', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['o', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 14/200
# Batch : 60/77
# Training Loss : 0.305
# Validation loss: 0.347
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['j', 'k', 'e', 'e', 'q', 'e', '<PAD>']
# Target : ['e', 'e', 'e', 'j', 'k', 'q', '<EOS>', '<PAD>']
# Predict : ['e', 'e', 'e', 'j', 'k', 'q', '<EOS>', '<PAD>']
#
# Epoch : 15/200
# Batch : 0/77
# Training Loss : 0.346
# Validation loss: 0.342
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['w', 'x', 'x', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['w', 'x', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['x', 'x', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 15/200
# Batch : 30/77
# Training Loss : 0.313
# Validation loss: 0.310
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['y', 'g', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['g', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['g', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 15/200
# Batch : 60/77
# Training Loss : 0.272
# Validation loss: 0.305
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['s', 'v', 'h', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['h', 's', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['h', 's', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Epoch : 16/200
# Batch : 0/77
# Training Loss : 0.312
# Validation loss: 0.302
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['g', 'l', 'r', 'z', '<PAD>', '<PAD>', '<PAD>']
# Target : ['g', 'l', 'r', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['j', 'j', 'r', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 16/200
# Batch : 30/77
# Training Loss : 0.287
# Validation loss: 0.280
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['y', 'z', 's', 'f', 'p', 'k', '<PAD>']
# Target : ['f', 'k', 'p', 's', 'y', 'z', '<EOS>', '<PAD>']
# Predict : ['f', 'l', 'p', 's', 'y', 'z', '<EOS>', '<PAD>']
#
# Epoch : 16/200
# Batch : 60/77
# Training Loss : 0.247
# Validation loss: 0.278
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['x', 'w', 'z', 'e', '<PAD>', '<PAD>', '<PAD>']
# Target : ['e', 'w', 'x', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['e', 'w', 'w', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 17/200
# Batch : 0/77
# Training Loss : 0.286
# Validation loss: 0.272
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['s', 'f', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 17/200
# Batch : 30/77
# Training Loss : 0.263
# Validation loss: 0.258
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['q', 'l', 'f', 'j', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 'j', 'l', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 'j', 'l', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 17/200
# Batch : 60/77
# Training Loss : 0.226
# Validation loss: 0.253
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['z', 'e', 'k', 'h', 'u', 'z', 'b']
# Target : ['b', 'e', 'h', 'k', 'u', 'z', 'z', '<EOS>']
# Predict : ['b', 'e', 'j', 'k', 'u', 'z', 'z', '<EOS>']
#
# Epoch : 18/200
# Batch : 0/77
# Training Loss : 0.266
# Validation loss: 0.240
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['j', 'p', 'j', 'y', 'c', 'f', 'z']
# Target : ['c', 'f', 'j', 'j', 'p', 'y', 'z', '<EOS>']
# Predict : ['b', 'j', 'j', 'j', 'p', 'z', 'z', '<EOS>']
#
# Epoch : 18/200
# Batch : 30/77
# Training Loss : 0.238
# Validation loss: 0.241
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['i', 'h', 'c', 'c', 'x', 'n', '<PAD>']
# Target : ['c', 'c', 'h', 'i', 'n', 'x', '<EOS>', '<PAD>']
# Predict : ['c', 'c', 'h', 'l', 'n', 'x', '<EOS>', '<PAD>']
#
# Epoch : 18/200
# Batch : 60/77
# Training Loss : 0.206
# Validation loss: 0.225
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['g', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['g', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['g', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 19/200
# Batch : 0/77
# Training Loss : 0.232
# Validation loss: 0.218
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['q', 'h', 'u', 'y', 'r', 'u', '<PAD>']
# Target : ['h', 'q', 'r', 'u', 'u', 'y', '<EOS>', '<PAD>']
# Predict : ['i', 'q', 'q', 'u', 'u', 'y', '<EOS>', '<PAD>']
#
# Epoch : 19/200
# Batch : 30/77
# Training Loss : 0.211
# Validation loss: 0.214
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['g', 'u', 'g', 'd', 'e', '<PAD>', '<PAD>']
# Target : ['d', 'e', 'g', 'g', 'u', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['a', 'g', 'g', 'g', 'u', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 19/200
# Batch : 60/77
# Training Loss : 0.188
# Validation loss: 0.207
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['b', 'h', 'g', 'k', '<PAD>', '<PAD>', '<PAD>']
# Target : ['b', 'g', 'h', 'k', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['b', 'h', 'h', 'k', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 20/200
# Batch : 0/77
# Training Loss : 0.212
# Validation loss: 0.199
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['t', 'k', 'u', 'c', 'h', 'l', 'z']
# Target : ['c', 'h', 'k', 'l', 't', 'u', 'z', '<EOS>']
# Predict : ['c', 'h', 'k', 'l', 'q', 'u', 'z', '<EOS>']
#
# Epoch : 20/200
# Batch : 30/77
# Training Loss : 0.193
# Validation loss: 0.196
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['n', 'k', 'i', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['i', 'k', 'n', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['i', 'k', 'n', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 20/200
# Batch : 60/77
# Training Loss : 0.174
# Validation loss: 0.191
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['s', 'n', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['n', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['n', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 21/200
# Batch : 0/77
# Training Loss : 0.194
# Validation loss: 0.182
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['f', 'h', 'h', 'l', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 'h', 'h', 'l', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 'h', 'h', 'l', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 21/200
# Batch : 30/77
# Training Loss : 0.176
# Validation loss: 0.181
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['d', 'p', 'i', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['d', 'i', 'p', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['d', 'i', 'p', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 21/200
# Batch : 60/77
# Training Loss : 0.161
# Validation loss: 0.177
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['p', 'q', 's', 'r', 't', 'y', '<PAD>']
# Target : ['p', 'q', 'r', 's', 't', 'y', '<EOS>', '<PAD>']
# Predict : ['p', 'q', 'r', 't', 't', 'w', '<EOS>', '<PAD>']
#
# Epoch : 22/200
# Batch : 0/77
# Training Loss : 0.179
# Validation loss: 0.169
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['p', 'r', 'u', 'h', 'c', 'j', '<PAD>']
# Target : ['c', 'h', 'j', 'p', 'r', 'u', '<EOS>', '<PAD>']
# Predict : ['c', 'h', 'j', 'p', 'r', 'u', '<EOS>', '<PAD>']
#
# Epoch : 22/200
# Batch : 30/77
# Training Loss : 0.162
# Validation loss: 0.168
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['j', 'e', 'i', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['e', 'i', 'j', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['e', 'i', 'j', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 22/200
# Batch : 60/77
# Training Loss : 0.150
# Validation loss: 0.165
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['b', 'c', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['b', 'c', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['b', 'c', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 23/200
# Batch : 0/77
# Training Loss : 0.164
# Validation loss: 0.157
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['t', 'j', 'e', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['e', 'j', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['e', 'j', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 23/200
# Batch : 30/77
# Training Loss : 0.149
# Validation loss: 0.157
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['b', 'w', 't', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['b', 't', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['b', 't', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 23/200
# Batch : 60/77
# Training Loss : 0.139
# Validation loss: 0.155
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['p', 'd', 'c', 'g', 'g', '<PAD>', '<PAD>']
# Target : ['c', 'd', 'g', 'g', 'p', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['a', 'd', 'g', 'g', 'p', '<EOS>', '<PAD>', '<PAD>']
# Epoch : 24/200
# Batch : 0/77
# Training Loss : 0.151
# Validation loss: 0.147
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['y', 'z', 'n', 's', '<PAD>', '<PAD>', '<PAD>']
# Target : ['n', 's', 'y', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['n', 's', 'y', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 24/200
# Batch : 30/77
# Training Loss : 0.139
# Validation loss: 0.145
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['d', 'u', 'z', 'f', '<PAD>', '<PAD>', '<PAD>']
# Target : ['d', 'f', 'u', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['d', 'f', 'u', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 24/200
# Batch : 60/77
# Training Loss : 0.129
# Validation loss: 0.144
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['c', 'm', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['c', 'm', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['c', 'm', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 25/200
# Batch : 0/77
# Training Loss : 0.137
# Validation loss: 0.138
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['o', 'j', 'w', 'b', '<PAD>', '<PAD>', '<PAD>']
# Target : ['b', 'j', 'o', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['b', 'j', 'o', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 25/200
# Batch : 30/77
# Training Loss : 0.130
# Validation loss: 0.134
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['v', 'p', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['p', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['p', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 25/200
# Batch : 60/77
# Training Loss : 0.120
# Validation loss: 0.134
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['r', 'x', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['r', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['r', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 26/200
# Batch : 0/77
# Training Loss : 0.126
# Validation loss: 0.129
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['w', 'x', 'x', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['w', 'x', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['x', 'x', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 26/200
# Batch : 30/77
# Training Loss : 0.122
# Validation loss: 0.127
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['s', 'o', 'v', 'y', 't', '<PAD>', '<PAD>']
# Target : ['o', 's', 't', 'v', 'y', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['o', 's', 't', 'v', 'y', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 26/200
# Batch : 60/77
# Training Loss : 0.112
# Validation loss: 0.125
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['c', 'h', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['c', 'h', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['c', 'h', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 27/200
# Batch : 0/77
# Training Loss : 0.116
# Validation loss: 0.122
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['k', 'o', 'l', 't', 'm', '<PAD>', '<PAD>']
# Target : ['k', 'l', 'm', 'o', 't', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['k', 'l', 'm', 'o', 't', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 27/200
# Batch : 30/77
# Training Loss : 0.115
# Validation loss: 0.122
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['i', 'x', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['i', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['i', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 27/200
# Batch : 60/77
# Training Loss : 0.105
# Validation loss: 0.117
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['s', 'v', 'h', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['h', 's', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['h', 's', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 28/200
# Batch : 0/77
# Training Loss : 0.107
# Validation loss: 0.114
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['s', 'n', 's', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['n', 's', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['n', 's', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 28/200
# Batch : 30/77
# Training Loss : 0.103
# Validation loss: 0.115
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['q', 'o', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['o', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['o', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 28/200
# Batch : 60/77
# Training Loss : 0.100
# Validation loss: 0.111
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['m', 'u', 'r', 'm', 'j', 'c', 'g']
# Target : ['c', 'g', 'j', 'm', 'm', 'r', 'u', '<EOS>']
# Predict : ['c', 'g', 'j', 'm', 'm', 'r', 'u', '<EOS>']
#
# Epoch : 29/200
# Batch : 0/77
# Training Loss : 0.105
# Validation loss: 0.111
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['w', 't', 'l', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['l', 't', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['l', 't', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 29/200
# Batch : 30/77
# Training Loss : 0.100
# Validation loss: 0.124
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['w', 'r', 'o', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['o', 'r', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['o', 'r', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 29/200
# Batch : 60/77
# Training Loss : 0.097
# Validation loss: 0.105
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['h', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['h', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['h', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 30/200
# Batch : 0/77
# Training Loss : 0.095
# Validation loss: 0.104
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['j', 'c', 's', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['c', 'j', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['c', 'j', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 30/200
# Batch : 30/77
# Training Loss : 0.090
# Validation loss: 0.100
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['t', 'e', 'f', 't', 'e', 't', 't']
# Target : ['e', 'e', 'f', 't', 't', 't', 't', '<EOS>']
# Predict : ['e', 'e', 'f', 't', 't', 't', 't', '<EOS>']
#
# Epoch : 30/200
# Batch : 60/77
# Training Loss : 0.090
# Validation loss: 0.094
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['x', 'q', 'q', 'i', 'k', 'u', 't']
# Target : ['i', 'k', 'q', 'q', 't', 'u', 'x', '<EOS>']
# Predict : ['i', 'k', 'q', 'q', 't', 'u', 'x', '<EOS>']
#
# Epoch : 31/200
# Batch : 0/77
# Training Loss : 0.087
# Validation loss: 0.097
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['k', 'j', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['j', 'k', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['j', 'k', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 31/200
# Batch : 30/77
# Training Loss : 0.085
# Validation loss: 0.094
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['f', 'm', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 'm', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 'm', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Epoch : 31/200
# Batch : 60/77
# Training Loss : 0.083
# Validation loss: 0.088
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['x', 'f', 'g', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 'g', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 'g', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 32/200
# Batch : 0/77
# Training Loss : 0.081
# Validation loss: 0.092
# stop_early : 0
# coin_tossing : [False  True  True  True  True  True  True  True]
# Source : ['g', 'q', 'f', 'g', 'p', 'l', '<PAD>']
# Target : ['f', 'g', 'g', 'l', 'p', 'q', '<EOS>', '<PAD>']
# Predict : ['d', 'g', 'g', 'l', 'p', 'q', '<EOS>', '<PAD>']
#
# Epoch : 32/200
# Batch : 30/77
# Training Loss : 0.079
# Validation loss: 0.089
# stop_early : 0
# coin_tossing : [False  True  True  True  True  True  True  True]
# Source : ['g', 'v', 'v', 'q', 'u', 'r', '<PAD>']
# Target : ['g', 'q', 'r', 'u', 'v', 'v', '<EOS>', '<PAD>']
# Predict : ['g', 'q', 'r', 'v', 'v', 'v', '<EOS>', '<PAD>']
#
# Epoch : 32/200
# Batch : 60/77
# Training Loss : 0.078
# Validation loss: 0.084
# stop_early : 0
# coin_tossing : [False  True  True  True  True  True  True  True]
# Source : ['a', 'w', 'k', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['a', 'k', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['a', 'k', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 33/200
# Batch : 0/77
# Training Loss : 0.076
# Validation loss: 0.087
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['e', 'k', 'e', 'j', 'i', 'j', 'q']
# Target : ['e', 'e', 'i', 'j', 'j', 'k', 'q', '<EOS>']
# Predict : ['e', 'e', 'i', 'j', 'j', 'k', 'q', '<EOS>']
#
# Epoch : 33/200
# Batch : 30/77
# Training Loss : 0.076
# Validation loss: 0.084
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['e', 'p', 's', 'g', 'q', 'v', '<PAD>']
# Target : ['e', 'g', 'p', 'q', 's', 'v', '<EOS>', '<PAD>']
# Predict : ['e', 'g', 'p', 'q', 's', 'v', '<EOS>', '<PAD>']
#
# Epoch : 33/200
# Batch : 60/77
# Training Loss : 0.072
# Validation loss: 0.080
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['b', 'z', 'e', 'p', 'j', 'v', '<PAD>']
# Target : ['b', 'e', 'j', 'p', 'v', 'z', '<EOS>', '<PAD>']
# Predict : ['b', 'e', 'j', 'p', 'v', 'z', '<EOS>', '<PAD>']
#
# Epoch : 34/200
# Batch : 0/77
# Training Loss : 0.071
# Validation loss: 0.082
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['y', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 34/200
# Batch : 30/77
# Training Loss : 0.073
# Validation loss: 0.079
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['s', 'o', 'v', 'y', 't', '<PAD>', '<PAD>']
# Target : ['o', 's', 't', 'v', 'y', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['o', 's', 't', 'v', 'y', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 34/200
# Batch : 60/77
# Training Loss : 0.065
# Validation loss: 0.075
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['u', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['u', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['u', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 35/200
# Batch : 0/77
# Training Loss : 0.067
# Validation loss: 0.077
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['q', 'h', 'u', 'y', 'r', 'u', '<PAD>']
# Target : ['h', 'q', 'r', 'u', 'u', 'y', '<EOS>', '<PAD>']
# Predict : ['h', 'q', 'r', 'u', 'u', 'y', '<EOS>', '<PAD>']
#
# Epoch : 35/200
# Batch : 30/77
# Training Loss : 0.069
# Validation loss: 0.076
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['a', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['a', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['a', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 35/200
# Batch : 60/77
# Training Loss : 0.060
# Validation loss: 0.071
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['e', 'c', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['c', 'e', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['c', 'e', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 36/200
# Batch : 0/77
# Training Loss : 0.062
# Validation loss: 0.074
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['q', 'd', 'm', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['d', 'm', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['d', 'm', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 36/200
# Batch : 30/77
# Training Loss : 0.067
# Validation loss: 0.077
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['y', 'g', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['g', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['g', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 36/200
# Batch : 60/77
# Training Loss : 0.057
# Validation loss: 0.068
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['i', 'k', 'c', 'z', 'c', '<PAD>', '<PAD>']
# Target : ['c', 'c', 'i', 'k', 'z', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['c', 'c', 'i', 'k', 'z', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 37/200
# Batch : 0/77
# Training Loss : 0.058
# Validation loss: 0.070
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['v', 'k', 'q', 'm', '<PAD>', '<PAD>', '<PAD>']
# Target : ['k', 'm', 'q', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['k', 'm', 'q', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 37/200
# Batch : 30/77
# Training Loss : 0.072
# Validation loss: 0.067
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['a', 'w', 'q', 'i', 'h', 'f', '<PAD>']
# Target : ['a', 'f', 'h', 'i', 'q', 'w', '<EOS>', '<PAD>']
# Predict : ['a', 'f', 'h', 'i', 'q', 'w', '<EOS>', '<PAD>']
#
# Epoch : 37/200
# Batch : 60/77
# Training Loss : 0.057
# Validation loss: 0.064
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['c', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['c', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['c', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 38/200
# Batch : 0/77
# Training Loss : 0.054
# Validation loss: 0.066
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['n', 'c', 'p', 'q', '<PAD>', '<PAD>', '<PAD>']
# Target : ['c', 'n', 'p', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['c', 'n', 'p', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 38/200
# Batch : 30/77
# Training Loss : 0.057
# Validation loss: 0.065
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['d', 'r', 'n', 'm', 'a', 'k', '<PAD>']
# Target : ['a', 'd', 'k', 'm', 'n', 'r', '<EOS>', '<PAD>']
# Predict : ['a', 'd', 'k', 'm', 'n', 'r', '<EOS>', '<PAD>']
#
# Epoch : 38/200
# Batch : 60/77
# Training Loss : 0.054
# Validation loss: 0.065
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['o', 'o', 'j', 'w', 't', 'm', 'b']
# Target : ['b', 'j', 'm', 'o', 'o', 't', 'w', '<EOS>']
# Predict : ['b', 'j', 'k', 'o', 'o', 't', 'w', '<EOS>']
#
# Epoch : 39/200
# Batch : 0/77
# Training Loss : 0.051
# Validation loss: 0.065
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['w', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 39/200
# Batch : 30/77
# Training Loss : 0.056
# Validation loss: 0.062
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['o', 'k', 'y', 'p', '<PAD>', '<PAD>', '<PAD>']
# Target : ['k', 'o', 'p', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['k', 'o', 'p', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Epoch : 39/200
# Batch : 60/77
# Training Loss : 0.052
# Validation loss: 0.063
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['l', 'k', 's', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['k', 'l', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['k', 'l', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 40/200
# Batch : 0/77
# Training Loss : 0.047
# Validation loss: 0.063
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['g', 'l', 'r', 'z', '<PAD>', '<PAD>', '<PAD>']
# Target : ['g', 'l', 'r', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['g', 'l', 'r', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 40/200
# Batch : 30/77
# Training Loss : 0.055
# Validation loss: 0.058
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['i', 'x', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['i', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['i', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 40/200
# Batch : 60/77
# Training Loss : 0.048
# Validation loss: 0.062
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['c', 'm', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['c', 'm', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['c', 'm', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 41/200
# Batch : 0/77
# Training Loss : 0.046
# Validation loss: 0.058
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['i', 'x', 'p', 'm', '<PAD>', '<PAD>', '<PAD>']
# Target : ['i', 'm', 'p', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['i', 'm', 'p', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 41/200
# Batch : 30/77
# Training Loss : 0.056
# Validation loss: 0.061
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['s', 'l', 'y', 't', '<PAD>', '<PAD>', '<PAD>']
# Target : ['l', 's', 't', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['l', 's', 't', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 41/200
# Batch : 60/77
# Training Loss : 0.047
# Validation loss: 0.057
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['x', 'k', 'd', 'g', '<PAD>', '<PAD>', '<PAD>']
# Target : ['d', 'g', 'k', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['d', 'g', 'k', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 42/200
# Batch : 0/77
# Training Loss : 0.046
# Validation loss: 0.056
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['q', 'r', 'y', 'c', 'a', 'j', '<PAD>']
# Target : ['a', 'c', 'j', 'q', 'r', 'y', '<EOS>', '<PAD>']
# Predict : ['a', 'c', 'j', 'q', 'r', 'y', '<EOS>', '<PAD>']
#
# Epoch : 42/200
# Batch : 30/77
# Training Loss : 0.047
# Validation loss: 0.054
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['w', 'y', 'u', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['u', 'w', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['u', 'w', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 42/200
# Batch : 60/77
# Training Loss : 0.041
# Validation loss: 0.052
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['z', 'm', 'j', 'k', 'p', 'c', '<PAD>']
# Target : ['c', 'j', 'k', 'm', 'p', 'z', '<EOS>', '<PAD>']
# Predict : ['c', 'j', 'k', 'm', 'p', 'z', '<EOS>', '<PAD>']
#
# Epoch : 43/200
# Batch : 0/77
# Training Loss : 0.042
# Validation loss: 0.053
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['o', 'f', 'q', 'q', 'e', 'r', 'n']
# Target : ['e', 'f', 'n', 'o', 'q', 'q', 'r', '<EOS>']
# Predict : ['e', 'f', 'n', 'o', 'q', 'q', 'r', '<EOS>']
#
# Epoch : 43/200
# Batch : 30/77
# Training Loss : 0.044
# Validation loss: 0.050
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['r', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['r', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['r', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 43/200
# Batch : 60/77
# Training Loss : 0.038
# Validation loss: 0.050
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['s', 't', 'x', 'i', '<PAD>', '<PAD>', '<PAD>']
# Target : ['i', 's', 't', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['i', 's', 't', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 44/200
# Batch : 0/77
# Training Loss : 0.039
# Validation loss: 0.050
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['t', 'r', 'i', 'f', 'z', 'r', 'j']
# Target : ['f', 'i', 'j', 'r', 'r', 't', 'z', '<EOS>']
# Predict : ['f', 'i', 'j', 'r', 'r', 't', 'z', '<EOS>']
#
# Epoch : 44/200
# Batch : 30/77
# Training Loss : 0.042
# Validation loss: 0.048
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['p', 'p', 'k', 'v', '<PAD>', '<PAD>', '<PAD>']
# Target : ['k', 'p', 'p', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['k', 'p', 'p', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 44/200
# Batch : 60/77
# Training Loss : 0.037
# Validation loss: 0.047
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['z', 'm', 'j', 'k', 'p', 'c', '<PAD>']
# Target : ['c', 'j', 'k', 'm', 'p', 'z', '<EOS>', '<PAD>']
# Predict : ['c', 'j', 'k', 'm', 'p', 'z', '<EOS>', '<PAD>']
#
# Epoch : 45/200
# Batch : 0/77
# Training Loss : 0.037
# Validation loss: 0.048
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['o', 'f', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 'o', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 'o', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 45/200
# Batch : 30/77
# Training Loss : 0.039
# Validation loss: 0.046
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['m', 'p', 'i', 'o', 'w', 'd', '<PAD>']
# Target : ['d', 'i', 'm', 'o', 'p', 'w', '<EOS>', '<PAD>']
# Predict : ['d', 'i', 'm', 'o', 'p', 'w', '<EOS>', '<PAD>']
#
# Epoch : 45/200
# Batch : 60/77
# Training Loss : 0.035
# Validation loss: 0.045
# stop_early : 0
# ...
# Source : ['l', 's', 't', 'f', 't', 'a', 'v']
# Target : ['a', 'f', 'l', 's', 't', 't', 'v', '<EOS>']
# Predict : ['b', 'f', 'l', 's', 't', 't', 'v', '<EOS>']
#
# Epoch : 99/200
# Batch : 30/77
# Training Loss : 0.032
# Validation loss: 0.049
# stop_early : 5
# coin_tossing : [False False False False False False False False]
# Source : ['i', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['i', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['i', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 99/200
# Batch : 60/77
# Training Loss : 0.028
# Validation loss: 0.046
# stop_early : 5
# coin_tossing : [False False False False False False False False]
# Source : ['d', 'i', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['d', 'i', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['d', 'i', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 100/200
# Batch : 0/77
# Training Loss : 0.035
# Validation loss: 0.048
# stop_early : 6
# coin_tossing : [False False False False False False False False]
# Source : ['y', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 100/200
# Batch : 30/77
# Training Loss : 0.029
# Validation loss: 0.045
# stop_early : 6
# coin_tossing : [False False False False False False False False]
# Source : ['m', 'w', 'f', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 'm', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 'm', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 100/200
# Batch : 60/77
# Training Loss : 0.026
# Validation loss: 0.044
# stop_early : 6
# coin_tossing : [False False False False False False False False]
# Source : ['h', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['h', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['h', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 101/200
# Batch : 0/77
# Training Loss : 0.031
# Validation loss: 0.044
# stop_early : 7
# coin_tossing : [False False False False False False False False]
# Source : ['j', 's', 'h', 'c', '<PAD>', '<PAD>', '<PAD>']
# Target : ['c', 'h', 'j', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['c', 'h', 'j', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 101/200
# Batch : 30/77
# Training Loss : 0.027
# Validation loss: 0.042
# stop_early : 7
# coin_tossing : [False False False False False False False False]
# Source : ['j', 'e', 'i', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['e', 'i', 'j', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['e', 'i', 'j', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 101/200
# Batch : 60/77
# Training Loss : 0.023
# Validation loss: 0.040
# stop_early : 7
# coin_tossing : [False False False False False False False False]
# Source : ['m', 'w', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['m', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['m', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 102/200
# Batch : 0/77
# Training Loss : 0.029
# Validation loss: 0.044
# stop_early : 8
# coin_tossing : [False False False False False False False False]
# Source : ['l', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['l', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['l', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 102/200
# Batch : 30/77
# Training Loss : 0.024
# Validation loss: 0.040
# stop_early : 8
# coin_tossing : [False False False False False False False False]
# Source : ['y', 'o', 's', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['o', 's', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['o', 's', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 102/200
# Batch : 60/77
# Training Loss : 0.020
# Validation loss: 0.037
# stop_early : 8
# coin_tossing : [False False False False False False False False]
# Source : ['w', 'v', 's', 'm', 'd', '<PAD>', '<PAD>']
# Target : ['d', 'm', 's', 'v', 'w', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['d', 'm', 's', 'v', 'w', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 103/200
# Batch : 0/77
# Training Loss : 0.025
# Validation loss: 0.041
# stop_early : 9
# coin_tossing : [False False False False False False False False]
# Source : ['t', 'e', 'z', 't', 'q', '<PAD>', '<PAD>']
# Target : ['e', 'q', 't', 't', 'z', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['e', 'q', 't', 't', 'z', '<EOS>', '<PAD>', '<PAD>']
# Epoch : 103/200
# Batch : 30/77
# Training Loss : 0.022
# Validation loss: 0.037
# stop_early : 9
# coin_tossing : [False False False False False False False False]
# Source : ['h', 'h', 'h', 'p', 'n', 'p', '<PAD>']
# Target : ['h', 'h', 'h', 'n', 'p', 'p', '<EOS>', '<PAD>']
# Predict : ['h', 'h', 'h', 'n', 'p', 'p', '<EOS>', '<PAD>']
#
# Epoch : 103/200
# Batch : 60/77
# Training Loss : 0.019
# Validation loss: 0.034
# stop_early : 9
# coin_tossing : [False False False False False False False False]
# Source : ['z', 'i', 'y', 'o', 'x', 'a', '<PAD>']
# Target : ['a', 'i', 'o', 'x', 'y', 'z', '<EOS>', '<PAD>']
# Predict : ['a', 'i', 'o', 'x', 'y', 'z', '<EOS>', '<PAD>']
#
# Epoch : 104/200
# Batch : 0/77
# Training Loss : 0.023
# Validation loss: 0.039
# stop_early : 10
# coin_tossing : [False False False False False False False False]
# Source : ['o', 'g', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['g', 'o', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['g', 'o', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 104/200
# Batch : 30/77
# Training Loss : 0.021
# Validation loss: 0.035
# stop_early : 10
# coin_tossing : [False False False False False False False False]
# Source : ['l', 'k', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['k', 'l', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['k', 'l', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 104/200
# Batch : 60/77
# Training Loss : 0.017
# Validation loss: 0.032
# stop_early : 10
# coin_tossing : [False False False False False False False False]
# Source : ['z', 'w', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['w', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['w', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 105/200
# Batch : 0/77
# Training Loss : 0.021
# Validation loss: 0.036
# stop_early : 11
# coin_tossing : [False False False False False False False False]
# Source : ['g', 'm', 't', 'm', 'g', 'z', '<PAD>']
# Target : ['g', 'g', 'm', 'm', 't', 'z', '<EOS>', '<PAD>']
# Predict : ['g', 'g', 'm', 'm', 't', 'z', '<EOS>', '<PAD>']
#
# Epoch : 105/200
# Batch : 30/77
# Training Loss : 0.019
# Validation loss: 0.033
# stop_early : 11
# coin_tossing : [False False False False False False False False]
# Source : ['i', 'x', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['i', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['i', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 105/200
# Batch : 60/77
# Training Loss : 0.015
# Validation loss: 0.030
# stop_early : 11
# coin_tossing : [False False False False False False False False]
# Source : ['s', 'q', 't', 't', '<PAD>', '<PAD>', '<PAD>']
# Target : ['q', 's', 't', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['q', 's', 't', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 106/200
# Batch : 0/77
# Training Loss : 0.019
# Validation loss: 0.034
# stop_early : 12
# coin_tossing : [False False False False False False False False]
# Source : ['r', 'f', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 'r', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 'r', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 106/200
# Batch : 30/77
# Training Loss : 0.018
# Validation loss: 0.031
# stop_early : 12
# coin_tossing : [False False False False False False False False]
# Source : ['b', 'w', 'u', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['b', 'u', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['b', 'u', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 106/200
# Batch : 60/77
# Training Loss : 0.014
# Validation loss: 0.028
# stop_early : 12
# coin_tossing : [False False False False False False False False]
# Source : ['r', 'y', 'i', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['i', 'r', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['i', 'r', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 107/200
# Batch : 0/77
# Training Loss : 0.018
# Validation loss: 0.032
# stop_early : 13
# coin_tossing : [False False False False False False False False]
# Source : ['l', 'a', 'a', 'f', 'f', 'u', 'g']
# Target : ['a', 'a', 'f', 'f', 'g', 'l', 'u', '<EOS>']
# Predict : ['a', 'a', 'f', 'f', 'g', 'l', 'u', '<EOS>']
#
# Epoch : 107/200
# Batch : 30/77
# Training Loss : 0.016
# Validation loss: 0.029
# stop_early : 13
# coin_tossing : [False False False False False False False False]
# Source : ['o', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['o', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['o', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 107/200
# Batch : 60/77
# Training Loss : 0.013
# Validation loss: 0.027
# stop_early : 13
# coin_tossing : [False False False False False False False False]
# Source : ['u', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['u', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['u', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 108/200
# Batch : 0/77
# Training Loss : 0.017
# Validation loss: 0.031
# stop_early : 14
# coin_tossing : [False False False False False False False False]
# Source : ['v', 'k', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['k', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['k', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 108/200
# Batch : 30/77
# Training Loss : 0.015
# Validation loss: 0.028
# stop_early : 14
# coin_tossing : [False False False False False False False False]
# Source : ['y', 'q', 'w', 'a', '<PAD>', '<PAD>', '<PAD>']
# Target : ['a', 'q', 'w', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['a', 'q', 'w', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 108/200
# Batch : 60/77
# Training Loss : 0.012
# Validation loss: 0.025
# stop_early : 14
# coin_tossing : [False False False False False False False False]
# Source : ['h', 'e', 'k', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['e', 'h', 'k', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['e', 'h', 'k', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 109/200
# Batch : 0/77
# Training Loss : 0.015
# Validation loss: 0.029
# stop_early : 15
# coin_tossing : [False False False False False False False False]
# Source : ['p', 'r', 'u', 'h', 'c', 'j', '<PAD>']
# Target : ['c', 'h', 'j', 'p', 'r', 'u', '<EOS>', '<PAD>']
# Predict : ['c', 'h', 'j', 'p', 'r', 'u', '<EOS>', '<PAD>']
#
# Epoch : 109/200
# Batch : 30/77
# Training Loss : 0.014
# Validation loss: 0.026
# stop_early : 15
# coin_tossing : [False False False False False False False False]
# Source : ['m', 'q', 'm', 'w', 'u', 'l', '<PAD>']
# Target : ['l', 'm', 'm', 'q', 'u', 'w', '<EOS>', '<PAD>']
# Predict : ['l', 'm', 'm', 'q', 'u', 'w', '<EOS>', '<PAD>']
#
# Epoch : 109/200
# Batch : 60/77
# Training Loss : 0.011
# Validation loss: 0.024
# stop_early : 15
# coin_tossing : [False False False False False False False False]
# Source : ['u', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['u', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['u', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 110/200
# Batch : 0/77
# Training Loss : 0.014
# Validation loss: 0.027
# stop_early : 16
# coin_tossing : [False False False False False False False False]
# Source : ['e', 'k', 'e', 'j', 'i', 'j', 'q']
# Target : ['e', 'e', 'i', 'j', 'j', 'k', 'q', '<EOS>']
# Predict : ['e', 'e', 'i', 'j', 'j', 'k', 'q', '<EOS>']
#
# Epoch : 110/200
# Batch : 30/77
# Training Loss : 0.013
# Validation loss: 0.025
# stop_early : 16
# coin_tossing : [False False False False False False False False]
# Source : ['d', 'p', 'i', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['d', 'i', 'p', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['d', 'i', 'p', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 110/200
# Batch : 60/77
# Training Loss : 0.011
# Validation loss: 0.023
# stop_early : 16
# coin_tossing : [False False False False False False False False]
# Source : ['u', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['u', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['u', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Epoch : 111/200
# Batch : 0/77
# Training Loss : 0.013
# Validation loss: 0.026
# stop_early : 17
# coin_tossing : [False False False False False False False False]
# Source : ['r', 'r', 'y', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['r', 'r', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['r', 'r', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 111/200
# Batch : 30/77
# Training Loss : 0.012
# Validation loss: 0.023
# stop_early : 17
# coin_tossing : [False False False False False False False False]
# Source : ['q', 'l', 'f', 'j', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 'j', 'l', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 'j', 'l', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 111/200
# Batch : 60/77
# Training Loss : 0.010
# Validation loss: 0.023
# stop_early : 17
# coin_tossing : [False False False False False False False False]
# Source : ['c', 'm', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['c', 'm', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['c', 'm', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 112/200
# Batch : 0/77
# Training Loss : 0.012
# Validation loss: 0.025
# stop_early : 18
# coin_tossing : [False False False False False False False False]
# Source : ['r', 'j', 'q', 't', 'r', 'j', 'b']
# Target : ['b', 'j', 'j', 'q', 'r', 'r', 't', '<EOS>']
# Predict : ['b', 'j', 'j', 'q', 'r', 'r', 't', '<EOS>']
#
# Epoch : 112/200
# Batch : 30/77
# Training Loss : 0.011
# Validation loss: 0.022
# stop_early : 18
# coin_tossing : [False False False False False False False False]
# Source : ['b', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['b', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['b', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 112/200
# Batch : 60/77
# Training Loss : 0.009
# Validation loss: 0.022
# stop_early : 18
# coin_tossing : [False False False False False False False False]
# Source : ['s', 'i', 'r', 'e', 'n', 'w', 'g']
# Target : ['e', 'g', 'i', 'n', 'r', 's', 'w', '<EOS>']
# Predict : ['e', 'g', 'i', 'n', 'r', 's', 'w', '<EOS>']
#
# Epoch : 113/200
# Batch : 0/77
# Training Loss : 0.011
# Validation loss: 0.024
# stop_early : 19
# coin_tossing : [False False False False False False False False]
# Source : ['u', 'f', 'n', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 'n', 'u', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 'n', 'u', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 113/200
# Batch : 30/77
# Training Loss : 0.010
# Validation loss: 0.021
# stop_early : 19
# coin_tossing : [False False False False False False False False]
# Source : ['i', 'h', 'f', 'o', 'o', '<PAD>', '<PAD>']
# Target : ['f', 'h', 'i', 'o', 'o', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['f', 'h', 'i', 'o', 'o', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 113/200
# Batch : 60/77
# Training Loss : 0.008
# Validation loss: 0.022
# stop_early : 19
# coin_tossing : [False False False False False False False False]
# Source : ['k', 'c', 'p', 'p', '<PAD>', '<PAD>', '<PAD>']
# Target : ['c', 'k', 'p', 'p', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['c', 'k', 'p', 'p', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Model Trained and Saved

# %% [markdown]
# ## Testing

# %%
import os    
sess = tf.Session()
new_saver = tf.train.import_meta_graph(os.path.join('trained_model/save_net.meta'))
new_saver.restore(sess, tf.train.latest_checkpoint(os.path.join('trained_model')))

graph = tf.get_default_graph()
input_data = graph.get_tensor_by_name('inputs:0')
targets = graph.get_tensor_by_name('targets:0')
predicting_logits = graph.get_tensor_by_name('predictions:0')
from_model_or_target = graph.get_tensor_by_name('on_train:0')

input_word = 'common'

test_source = [] 
for letter in input_word:
    if letter not in source_letter_to_int.keys():
        test_source.append(source_letter_to_int['<UNK>'])
    else:
        test_source.append(source_letter_to_int[letter])
        
# 輸入的句子的長度是固定source_max_length，所以補source_letter_to_int['<PAD>']到長度為source_max_length
while len(test_source) < source_max_length:
    test_source.append(source_letter_to_int['<PAD>'])
test_source = [test_source] * batch_size   
        
# test_target輸入的值可以隨便選，只要長度為target_max_length即可    
test_target = [0 for _ in range(0 , target_max_length)] 
test_target = [test_target] * batch_size

test_source = np.array(test_source)
test_target = np.array(test_target)
answer = sess.run(predicting_logits , feed_dict = {input_data : test_source ,
                                                   targets : test_target ,
                                                   from_model_or_target : coin_tossing})

answer = answer[0 , :]
answer_to_letter = []
for num in answer:
    answer_to_letter.append(target_int_to_letter[num])
print(answer_to_letter)
# Out:
# INFO:tensorflow:Restoring parameters from trained_model\save_net
# ['c', 'm', 'm', 'n', 'o', 'o', '<EOS>', '<PAD>']
