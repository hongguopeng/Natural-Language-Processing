# %% [markdown]
# # Seq2Seq
# 實現基礎版的Seq2Seq，輸入一個英文單字，模型將輸出一個對字母排序後的單字
# <br>輸入 : hello
# <br>輸出 : ehllo

# %% [markdown]
# 本程式試著不使用Tensorflow所提供的Helper指令，完成Scheduled Sampling<br>
# Scheduled Sampling是一種解決訓練和生成時輸入數據分布不一致的方法<br>
#
# 在一般的Seq2Seq模型的inference階段中，如果Sequence中在t時刻中產生錯誤的值，在t時刻之後的輸入狀態將會受到影響，而該誤差會隨著生成過程不斷向後累積；而Scheduled Sampling以一定概率將Decoder自己產生的值作為Decoder端的輸入，這樣即使前面產生錯誤的值，其目標仍然是最大化真實目標序列的概率，模型會朝著正確的方向進<br>
#
# 在訓練早期Scheduled Sampling主要使用target中的真實值作為Decoder端的輸入，可以將模型從隨機初始化的狀態快速引導至一個合理的狀態；隨著訓練的進行，該方法會逐漸更多地使用Decoder自己產生的值作為Decoder端的輸入，以解決數據分布不一致的問題<br>

# %% [markdown]
# <img src="3_scheduled_sampling_不使用helper指令_version_1.jpg" style="width:1140px;height:600px;float:middle">
#
# 以上為Decoder端的計算流程<br>
# 當前時刻decoder_cell會直接吃mlstm_cell_output(上一個時刻decoder_cell的輸出)<br>

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import time
import copy
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# %% [markdown]
# # 讀取數據

# %%
f = open('data/letters_source.txt', 'r', encoding = 'utf-8')
source_data = f.read()

f = open('data/letters_target.txt', 'r', encoding = 'utf-8')
target_data = f.read()

# %% [markdown]
# # 數據預處理

# %%
def extract_character_vocab(data):
    
    special_words = ['<PAD>' , '<UNK>' , '<GO>' , '<EOS>']
    
    words = []
    for line in data.split('\n'):
        for character in line:
            if character not in words:
                words.append(character)

    # 將四個特殊字加入詞庫       
    int_to_vocab = {idx: word for idx , word in enumerate(special_words + words)}
    vocab_to_int = dict(zip(int_to_vocab.values() , int_to_vocab.keys()))

    return int_to_vocab, vocab_to_int

# %%
source_int_to_letter , source_letter_to_int = extract_character_vocab(source_data)
target_int_to_letter , target_letter_to_int = extract_character_vocab(target_data)

# 將所有字母轉換成index
source_int = []
for line in source_data.split('\n'):
    temp = []
    for letter in line:
        temp.append(source_letter_to_int[letter])
    source_int.append(temp)    
        
target_int = []
for line in target_data.split('\n'):
    temp = []
    for letter in line:
        temp.append(target_letter_to_int[letter])
    temp = temp + [target_letter_to_int['<EOS>']]
    target_int.append(temp)

# %%
# 決定source_int與target_int中的最大長度
# 因為後面的decoder的rnn不是使用tf.nn.dynamic_rnn，無法使用動態長度的功能，所以在這裡就要決定每個batch的長度
source_max_length , target_max_length = 0 , 0  
for vob_source , vob_target in zip(source_int , target_int):
    if len(vob_source) > source_max_length:
        source_max_length = len(vob_source)    
    if len(vob_target) > target_max_length:
        target_max_length = len(vob_target)  

# 分別對source_int與target_int_pad 補source_letter_to_int['<PAD>']與target_letter_to_int['<PAD>']到最大長度  
source_int_pad , target_int_pad = [] , []
for i_source , j_target in zip(range(len(source_int)) , range(len(target_int))):
    temp_source = source_int[i_source].copy()
    while len(temp_source) < source_max_length:
        temp_source.append(source_letter_to_int['<PAD>']) 
    source_int_pad.append(temp_source)
    
    temp_target = target_int[j_target].copy()
    while len(temp_target) < target_max_length:
        temp_target.append(target_letter_to_int['<PAD>']) 
    target_int_pad.append(temp_target)       

source_int_pad = np.array(source_int_pad)
target_int_pad = np.array(target_int_pad)

# %%
# 超參數
# Number of Epochs
epochs = 200
# Batch Size
batch_size = 128
# RNN Size
rnn_hidden_unit = 50
# Number of Layers
num_layers = 1
# Embedding Size
encoding_embedding_size = 15
decoding_embedding_size = rnn_hidden_unit
# Learning Rate
learning_rate = 0.001
source_vocab_size = len(source_int_to_letter)
target_vocab_size = len(target_int_to_letter)

# %% [markdown]
# # Build Model

# %% [markdown]
# ## 輸入層

# %%
input_data = tf.placeholder(tf.int32, [None , source_max_length] , name = 'inputs')
targets = tf.placeholder(tf.int32, [None , target_max_length] , name = 'targets')
targets_onehot = tf.one_hot(tf.reshape(targets , [-1]) , depth = target_vocab_size)
lr = tf.placeholder(tf.float32 , name = 'learning_rate')

# 決定到底是"t-1階段的輸出"還是"target中的真實答案"，當作t階段的輸入
from_model_or_target = tf.placeholder(tf.bool , [target_max_length , ] , name = 'on_train')

# %% [markdown]
# ## Encoder

# %% [markdown]
# 需要對source數據進行embedding，再傳入Decoder中的RNN

# %%
# input_data: 輸入tensor
# rnn_hidden_unit: rnn隱層結點數量
# num_layers: rnn cell的層數
# source_sequence_length: source數據的序列長度
# source_vocab_size: source數據的詞庫大小
# encoding_embedding_size: embedding的向量維度

# Encoder embedding
'''
encoder_embed_input = tf.contrib.layers.embed_sequence(input_data , source_vocab_size , encoding_embedding_size) 
                                                  ⇕ 相當於
encoder_embeddings = tf.Variable(tf.random_uniform([source_vocab_size , encoding_embedding_size]))
encoder_embed_input = tf.nn.embedding_lookup(encoder_embeddings , input_data)

若懶得寫兩行程式可以直接用tf.contrib.layers.embed_sequence這個函數
介紹 : https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence
'''
encoder_embeddings = tf.Variable(tf.random_uniform([source_vocab_size , encoding_embedding_size]))
encoder_embed_input = tf.nn.embedding_lookup(encoder_embeddings , input_data)

def get_lstm_cell(rnn_hidden_unit):
    lstm_cell = tf.contrib.rnn.LSTMCell(rnn_hidden_unit, 
                                        initializer = tf.random_uniform_initializer(-0.1 , 0.1))
    return lstm_cell

with tf.variable_scope('encoder'):   
    encoder_cell = tf.contrib.rnn.MultiRNNCell([get_lstm_cell(rnn_hidden_unit) for _ in range(num_layers)])
    
    encoder_output, encoder_state = tf.nn.dynamic_rnn(encoder_cell , 
                                                      encoder_embed_input, 
                                                      dtype = tf.float32)

# %% [markdown]
# ## Decoder

# %%
# 預處理後的decoder輸入
# 在batch中每一筆data最前面加上<GO>，並移除最後一個字，所以每一筆data的詞的數目並無改變

# cut掉最後一個字
# ending = tf.strided_slice(targets , [0, 0] , [batch_size, -1] , [1, 1]) # 等同於 ending = tf.identity(targets[: , 0:-1])
ending = tf.identity(targets[: , 0:-1])
decoder_input = tf.concat([tf.fill([batch_size, 1] , target_letter_to_int['<GO>']) , ending] , axis = 1)

# %%
# decoding_embedding_size: embedding的向量維度
# num_layers: rnn cell的層數
# rnn_size: RNN單元的隱層結點數量
# encoder_state: encoder端編碼的狀態向量
# decoder_input: decoder端輸入

# 1. Embedding
decoder_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
decoder_embed_input = tf.nn.embedding_lookup(decoder_embeddings , decoder_input)

with tf.variable_scope('decoder'):
    # 2. 建造Decoder中的RNN單元
    decoder_cell = tf.contrib.rnn.MultiRNNCell([get_lstm_cell(rnn_hidden_unit) for _ in range(num_layers)])
    state = encoder_state 
    outputs  = []
    for time_step in range(0 , target_max_length):
        if time_step > 0: tf.get_variable_scope().reuse_variables()  
        
        # 在訓練的過程中，除了time_step為0以外，每一個time_step都投擲硬幣決定
        # 要用decoder_embed_input[: , time_step , :](target中的真實答案)，還是mlstm_cell_output(machine自己產生的output)，輸入decoder_cell
        # 正面代表當前時刻decoder_cell要吃decoder_embed_input[: , time_step , :](target中的真實答案)
        # 反面代表當前時刻decoder_cell要吃mlstm_cell_output(上一個時刻decoder_cell的輸出)
        # 也就是coin tossing為[True , True , True , True , True , True , True , True]會逐漸變為[Faslse , Faslse , Faslse , Faslse , Faslse , Faslse , Faslse , Faslse]
        # 前幾個epoch會有很大的機率擲出正面，但隨著訓練的過程擲出反面的機率會越來越大
        # 在後面的步驟會調節擲出正反面的機率
        if time_step == 0: 
            input_to_decoder = decoder_embed_input[: , 0 , :]
            mlstm_cell_output , state = decoder_cell(input_to_decoder , state)
                
        elif time_step > 0: 
            input_to_decoder = tf.cond(from_model_or_target[time_step] , 
                                       lambda: decoder_embed_input[: , time_step , :] , 
                                       lambda: mlstm_cell_output)
            mlstm_cell_output , state = decoder_cell(input_to_decoder , state)
        
        outputs.append(mlstm_cell_output)

# %%
outputs_ = tf.transpose(tf.convert_to_tensor(outputs) , [1 , 0 , 2])    
outputs_ = tf.reshape(outputs_ , [-1 , rnn_hidden_unit]) 

weights = tf.Variable(tf.truncated_normal([rnn_hidden_unit , target_vocab_size] , mean = 0.01 , stddev = 0.1))
biases = tf.Variable(tf.zeros([1 , target_vocab_size]) + 0.0001)
logits = tf.matmul(outputs_ , weights) + biases 

# predicting_logits與訓練無關，純粹只是要看結果
predicting_logits = tf.nn.softmax(logits)   
predicting_logits = tf.argmax(predicting_logits , axis = 1)
predicting_logits = tf.reshape(predicting_logits , [batch_size , -1] , name = 'predictions')

# %%
# Loss function
loss = tf.nn.softmax_cross_entropy_with_logits(labels = targets_onehot , logits = logits)
total_loss = tf.reduce_mean(loss)

# Optimizer
optimizer = tf.train.AdamOptimizer(lr)

# Gradient Clipping
gradients = optimizer.compute_gradients(total_loss)
capped_gradients = [(tf.clip_by_value(grad, -5. , 5.), var) for grad, var in gradients if grad is not None]
train_op = optimizer.apply_gradients(capped_gradients)
# Out:
# WARNING:tensorflow:From <ipython-input-12-0dda0281734f>:2: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %%
# 將數據集分割為train和validation
train_source = source_int_pad[batch_size:]
train_target = target_int_pad[batch_size:]
# 留出一個batch進行驗證
valid_source = source_int_pad[:batch_size]
valid_target = target_int_pad[:batch_size]

# %% [markdown]
# ## Training

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

prob = 1e-3
alpha = 1.075
stop_early = 0
for epoch_i in range(0 , epochs):
    
    # 在每進行一個epoch前，把每個batch的index先決定出來
    batch_index = []
    temp = []
    count = 0 # 隨機決定index的開頭 
    while len(batch_index) <= 77:  # 1個batch裡只有77筆資料
        temp.append(count)
        count += 1
        if len(temp) == batch_size:
            batch_index.append(temp)
            temp = []
        if count == len(train_source):
            count = 0
    
    # 一開始會出現[True , True , True , True , True , True , True , True]
    # 隨著epoch的增長，逐漸開始出現[Faslse , Faslse , Faslse , Faslse , Faslse , Faslse , Faslse , Faslse]
    # 在Decoder端的訓練，一開始t階段的輸入為t-1階段的期望輸出(Teacher Forcing)，到最後逐漸變為t階段的輸入為t-1階段的輸出(Sampling)
    coin_tossing = np.random.choice(a = 2 , 
                                    size = target_max_length , 
                                    replace = True , 
                                    p = [prob , 1 - prob])
    coin_tossing = coin_tossing.astype(bool)
    if alpha * prob < 1  : prob = alpha * prob # p會隨著epoch增加越來越大
    elif alpha * prob > 1: prob = 1.        

    for batch_i in range(0 , 77):
        train_source_batch , train_target_batch =\
        train_source[batch_index[batch_i] , :] , train_target[batch_index[batch_i] , :] 
        
        _ , training_loss , predicting_logits_result =\
        sess.run([train_op, total_loss , predicting_logits] , 
                 feed_dict = {input_data : train_source_batch ,
                              targets : train_target_batch ,
                              from_model_or_target : coin_tossing ,
                              lr: learning_rate})
   
        if batch_i % 30 == 0: # 每隔30個輪查看一下結果
            validation_loss = sess.run(total_loss, 
                                       feed_dict = {input_data : valid_source ,
                                                    targets : valid_target ,
                                                    from_model_or_target : coin_tossing}) 

            print('Epoch : {}/{} \nBatch : {}/{} \nTraining Loss : {:.3f} \nValidation loss: {:.3f} \nstop_early : {} \ncoin_tossing : {}'
                  .format(epoch_i , epochs , 
                          batch_i , len(train_source) // batch_size , 
                          training_loss , validation_loss , 
                          stop_early , coin_tossing))
            
            index = np.random.randint(batch_size)
            print('Source : {}'.format([source_int_to_letter[i] for i in train_source_batch[index]] ))
            print('Target : {}'.format([target_int_to_letter[i] for i in train_target_batch[index]] ))
            print('Predict : {}\n'.format([target_int_to_letter[i] for i in predicting_logits_result[index]] ))
        
    if coin_tossing.sum() == 0:
        stop_early += 1

    if stop_early == 20: # 當coin_tossing全部為False的次數為20時即停止計算
        break        
    
    
# 保存模型
saver = tf.train.Saver()
saver.save(sess , 'trained_model/save_net')
print('Model Trained and Saved')
# Out:
# Epoch : 0/200
# Batch : 0/77
# Training Loss : 3.353
# Validation loss: 3.302
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['q', 'v', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['q', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['s', 'p', 'p', 'p', 'p', 'p', 'p', 'p']
#
# Epoch : 0/200
# Batch : 30/77
# Training Loss : 2.367
# Validation loss: 2.331
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['m', 'q', 's', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['m', 'q', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 0/200
# Batch : 60/77
# Training Loss : 1.939
# Validation loss: 1.966
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['o', 'x', 'g', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['g', 'o', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['d', '<EOS>', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 1/200
# Batch : 0/77
# Training Loss : 1.929
# Validation loss: 1.807
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['w', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['<EOS>', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 1/200
# Batch : 30/77
# Training Loss : 1.654
# Validation loss: 1.632
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['m', 'q', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['m', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['g', '<EOS>', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 1/200
# Batch : 60/77
# Training Loss : 1.484
# Validation loss: 1.515
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['t', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['t', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['<EOS>', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 2/200
# Batch : 0/77
# Training Loss : 1.570
# Validation loss: 1.471
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['j', 'p', 'j', 'y', 'c', 'f', 'z']
# Target : ['c', 'f', 'j', 'j', 'p', 'y', 'z', '<EOS>']
# Predict : ['a', 'f', 'l', 'l', 't', 'x', '<EOS>', '<EOS>']
#
# Epoch : 2/200
# Batch : 30/77
# Training Loss : 1.435
# Validation loss: 1.417
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['s', 'm', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['m', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['g', '<EOS>', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 2/200
# Batch : 60/77
# Training Loss : 1.343
# Validation loss: 1.372
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['w', 'q', 'w', 'j', 'x', 'j', 'j']
# Target : ['j', 'j', 'j', 'q', 'w', 'w', 'x', '<EOS>']
# Predict : ['a', 'i', 'k', 'o', 'u', 'y', '<EOS>', '<EOS>']
#
# Epoch : 3/200
# Batch : 0/77
# Training Loss : 1.437
# Validation loss: 1.354
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['t', 'e', 'z', 't', 'q', '<PAD>', '<PAD>']
# Target : ['e', 'q', 't', 't', 'z', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['a', 'h', 'o', 'v', '<EOS>', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 3/200
# Batch : 30/77
# Training Loss : 1.331
# Validation loss: 1.314
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['z', 'z', 'c', 's', 'f', 'h', 'u']
# Target : ['c', 'f', 'h', 's', 'u', 'z', 'z', '<EOS>']
# Predict : ['b', 'd', 'i', 'o', 'u', 'y', '<EOS>', '<EOS>']
#
# Epoch : 3/200
# Batch : 60/77
# Training Loss : 1.214
# Validation loss: 1.253
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['u', 'v', 'y', 'd', 'r', 'z', '<PAD>']
# Target : ['d', 'r', 'u', 'v', 'y', 'z', '<EOS>', '<PAD>']
# Predict : ['d', 'i', 'q', 'w', 'y', '<EOS>', '<EOS>', '<PAD>']
#
# Epoch : 4/200
# Batch : 0/77
# Training Loss : 1.292
# Validation loss: 1.213
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['h', 'c', 'd', 'o', '<PAD>', '<PAD>', '<PAD>']
# Target : ['c', 'd', 'h', 'o', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['a', 'c', 'l', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 4/200
# Batch : 30/77
# Training Loss : 1.163
# Validation loss: 1.143
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['z', 'q', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['q', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['q', '<EOS>', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 4/200
# Batch : 60/77
# Training Loss : 1.056
# Validation loss: 1.089
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['s', 'i', 'r', 'e', 'n', 'w', 'g']
# Target : ['e', 'g', 'i', 'n', 'r', 's', 'w', '<EOS>']
# Predict : ['a', 'f', 'i', 'l', 'o', 't', 'x', '<EOS>']
#
# Epoch : 5/200
# Batch : 0/77
# Training Loss : 1.137
# Validation loss: 1.057
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['v', 'q', 'i', 's', 't', 'a', 'i']
# Target : ['a', 'i', 'i', 'q', 's', 't', 'v', '<EOS>']
# Predict : ['a', 'h', 'h', 'q', 't', 't', 'v', '<EOS>']
#
# Epoch : 5/200
# Batch : 30/77
# Training Loss : 1.011
# Validation loss: 0.999
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['h', 'h', 'h', 'p', 'n', 'p', '<PAD>']
# Target : ['h', 'h', 'h', 'n', 'p', 'p', '<EOS>', '<PAD>']
# Predict : ['b', 'h', 'h', 'o', 's', 'v', '<EOS>', '<PAD>']
#
# Epoch : 5/200
# Batch : 60/77
# Training Loss : 0.937
# Validation loss: 0.955
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['k', 'o', 'd', 'f', '<PAD>', '<PAD>', '<PAD>']
# Target : ['d', 'f', 'k', 'o', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['a', 'f', 'l', 'l', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 6/200
# Batch : 0/77
# Training Loss : 1.012
# Validation loss: 0.925
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['w', 'r', 'q', 'd', '<PAD>', '<PAD>', '<PAD>']
# Target : ['d', 'q', 'r', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['h', 'p', 'r', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 6/200
# Batch : 30/77
# Training Loss : 0.896
# Validation loss: 0.887
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['v', 'f', 'p', 'b', 'o', 'n', 'q']
# Target : ['b', 'f', 'n', 'o', 'p', 'q', 'v', '<EOS>']
# Predict : ['b', 'd', 'f', 'n', 'r', 's', 'v', '<EOS>']
#
# Epoch : 6/200
# Batch : 60/77
# Training Loss : 0.844
# Validation loss: 0.848
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['u', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['u', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['u', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 7/200
# Batch : 0/77
# Training Loss : 0.909
# Validation loss: 0.826
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['n', 'c', 'p', 'q', '<PAD>', '<PAD>', '<PAD>']
# Target : ['c', 'n', 'p', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['e', 'p', 'p', 'r', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 7/200
# Batch : 30/77
# Training Loss : 0.802
# Validation loss: 0.789
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['i', 'm', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['i', 'm', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['i', 'k', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 7/200
# Batch : 60/77
# Training Loss : 0.744
# Validation loss: 0.761
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['w', 'z', 'p', 'v', 'b', 'w', 'u']
# Target : ['b', 'p', 'u', 'v', 'w', 'w', 'z', '<EOS>']
# Predict : ['h', 'p', 'u', 'w', 'y', 'y', '<EOS>', '<EOS>']
# Epoch : 8/200
# Batch : 0/77
# Training Loss : 0.806
# Validation loss: 0.735
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['s', 'd', 'v', 'm', 'f', '<PAD>', '<PAD>']
# Target : ['d', 'f', 'm', 's', 'v', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['c', 'f', 'p', 's', 'v', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 8/200
# Batch : 30/77
# Training Loss : 0.705
# Validation loss: 0.699
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['p', 'p', 'k', 'v', '<PAD>', '<PAD>', '<PAD>']
# Target : ['k', 'p', 'p', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['g', 'p', 'p', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 8/200
# Batch : 60/77
# Training Loss : 0.658
# Validation loss: 0.668
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['o', 't', 'n', 'y', '<PAD>', '<PAD>', '<PAD>']
# Target : ['n', 'o', 't', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['l', 'o', 't', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 9/200
# Batch : 0/77
# Training Loss : 0.713
# Validation loss: 0.650
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['q', 'r', 'y', 'c', 'a', 'j', '<PAD>']
# Target : ['a', 'c', 'j', 'q', 'r', 'y', '<EOS>', '<PAD>']
# Predict : ['a', 'a', 'm', 'q', 'r', 'w', '<EOS>', '<PAD>']
#
# Epoch : 9/200
# Batch : 30/77
# Training Loss : 0.617
# Validation loss: 0.624
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['o', 'j', 'z', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['j', 'o', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['j', 'o', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 9/200
# Batch : 60/77
# Training Loss : 0.586
# Validation loss: 0.591
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['a', 'v', 'd', 's', 'e', 's', 'c']
# Target : ['a', 'c', 'd', 'e', 's', 's', 'v', '<EOS>']
# Predict : ['b', 'c', 'c', 'g', 's', 's', 'v', '<EOS>']
#
# Epoch : 10/200
# Batch : 0/77
# Training Loss : 0.631
# Validation loss: 0.578
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['u', 'f', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 'u', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 'u', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 10/200
# Batch : 30/77
# Training Loss : 0.543
# Validation loss: 0.552
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['w', 'r', 'o', 'n', 'q', 'l', 'a']
# Target : ['a', 'l', 'n', 'o', 'q', 'r', 'w', '<EOS>']
# Predict : ['a', 'j', 'n', 'n', 'r', 'r', 'w', '<EOS>']
#
# Epoch : 10/200
# Batch : 60/77
# Training Loss : 0.514
# Validation loss: 0.525
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['c', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['c', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['b', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 11/200
# Batch : 0/77
# Training Loss : 0.560
# Validation loss: 0.512
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['s', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['s', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['s', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 11/200
# Batch : 30/77
# Training Loss : 0.476
# Validation loss: 0.489
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['b', 'w', 'u', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['b', 'u', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['b', 'u', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 11/200
# Batch : 60/77
# Training Loss : 0.447
# Validation loss: 0.464
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['x', 'r', 'x', 'm', '<PAD>', '<PAD>', '<PAD>']
# Target : ['m', 'r', 'x', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['m', 'r', 'u', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 12/200
# Batch : 0/77
# Training Loss : 0.496
# Validation loss: 0.451
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['h', 'v', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['h', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['h', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 12/200
# Batch : 30/77
# Training Loss : 0.413
# Validation loss: 0.431
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['r', 'q', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['q', 'r', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['q', 'r', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 12/200
# Batch : 60/77
# Training Loss : 0.388
# Validation loss: 0.409
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['l', 'n', 'l', 'x', 'b', 'a', '<PAD>']
# Target : ['a', 'b', 'l', 'l', 'n', 'x', '<EOS>', '<PAD>']
# Predict : ['b', 'b', 'l', 'l', 'n', 'x', '<EOS>', '<PAD>']
#
# Epoch : 13/200
# Batch : 0/77
# Training Loss : 0.438
# Validation loss: 0.398
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['z', 'e', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['e', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['e', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 13/200
# Batch : 30/77
# Training Loss : 0.361
# Validation loss: 0.378
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['e', 'i', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['e', 'i', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['e', 'i', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 13/200
# Batch : 60/77
# Training Loss : 0.338
# Validation loss: 0.360
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['w', 'q', 'w', 'j', 'x', 'j', 'j']
# Target : ['j', 'j', 'j', 'q', 'w', 'w', 'x', '<EOS>']
# Predict : ['j', 'j', 'j', 'q', 'w', 'w', 'w', '<EOS>']
#
# Epoch : 14/200
# Batch : 0/77
# Training Loss : 0.387
# Validation loss: 0.348
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['v', 'w', 'c', 'r', 'g', '<PAD>', '<PAD>']
# Target : ['c', 'g', 'r', 'v', 'w', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['c', 'c', 'r', 'v', 'w', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 14/200
# Batch : 30/77
# Training Loss : 0.316
# Validation loss: 0.332
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['a', 'b', 'q', 'k', 'q', 'l', 'p']
# Target : ['a', 'b', 'k', 'l', 'p', 'q', 'q', '<EOS>']
# Predict : ['a', 'a', 'h', 'h', 'q', 'q', 'v', '<EOS>']
#
# Epoch : 14/200
# Batch : 60/77
# Training Loss : 0.297
# Validation loss: 0.316
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['c', 'm', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['c', 'm', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['c', 'm', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 15/200
# Batch : 0/77
# Training Loss : 0.340
# Validation loss: 0.309
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['b', 'b', 'b', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['b', 'b', 'b', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['b', 'b', 'b', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 15/200
# Batch : 30/77
# Training Loss : 0.279
# Validation loss: 0.295
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['z', 'g', 'l', 'h', 'w', 'd', '<PAD>']
# Target : ['d', 'g', 'h', 'l', 'w', 'z', '<EOS>', '<PAD>']
# Predict : ['d', 'h', 'h', 'l', 'w', 'z', '<EOS>', '<PAD>']
#
# Epoch : 15/200
# Batch : 60/77
# Training Loss : 0.265
# Validation loss: 0.283
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['b', 'c', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['b', 'c', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['b', 'c', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Epoch : 16/200
# Batch : 0/77
# Training Loss : 0.302
# Validation loss: 0.278
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['z', 's', 'u', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['s', 'u', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['s', 'u', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 16/200
# Batch : 30/77
# Training Loss : 0.251
# Validation loss: 0.264
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['m', 'm', 'e', 't', 'm', 'z', '<PAD>']
# Target : ['e', 'm', 'm', 'm', 't', 'z', '<EOS>', '<PAD>']
# Predict : ['e', 'm', 'm', 'm', 'u', 'z', '<EOS>', '<PAD>']
#
# Epoch : 16/200
# Batch : 60/77
# Training Loss : 0.242
# Validation loss: 0.276
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['k', 'r', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['k', 'r', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['k', 'r', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 17/200
# Batch : 0/77
# Training Loss : 0.279
# Validation loss: 0.254
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['v', 'w', 'c', 'r', 'g', '<PAD>', '<PAD>']
# Target : ['c', 'g', 'r', 'v', 'w', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['c', 'c', 'r', 'v', 'w', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 17/200
# Batch : 30/77
# Training Loss : 0.227
# Validation loss: 0.238
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['k', 'o', 'k', 'g', 'd', '<PAD>', '<PAD>']
# Target : ['d', 'g', 'k', 'k', 'o', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['g', 'g', 'k', 'k', 'o', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 17/200
# Batch : 60/77
# Training Loss : 0.208
# Validation loss: 0.231
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['q', 'h', 'j', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['h', 'j', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['h', 'j', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 18/200
# Batch : 0/77
# Training Loss : 0.245
# Validation loss: 0.228
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['d', 'a', 'v', 'o', 'k', 'o', 'c']
# Target : ['a', 'c', 'd', 'k', 'o', 'o', 'v', '<EOS>']
# Predict : ['a', 'b', 'g', 'j', 'o', 'o', 'v', '<EOS>']
#
# Epoch : 18/200
# Batch : 30/77
# Training Loss : 0.206
# Validation loss: 0.217
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['f', 't', 'j', 'g', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 'g', 'j', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['g', 'g', 'j', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 18/200
# Batch : 60/77
# Training Loss : 0.188
# Validation loss: 0.209
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['a', 'v', 'd', 's', 'e', 's', 'c']
# Target : ['a', 'c', 'd', 'e', 's', 's', 'v', '<EOS>']
# Predict : ['a', 'c', 'e', 'e', 's', 's', 'v', '<EOS>']
#
# Epoch : 19/200
# Batch : 0/77
# Training Loss : 0.222
# Validation loss: 0.209
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['w', 't', 'l', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['l', 't', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['l', 't', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 19/200
# Batch : 30/77
# Training Loss : 0.190
# Validation loss: 0.200
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['c', 'a', 'x', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['a', 'c', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['a', 'c', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 19/200
# Batch : 60/77
# Training Loss : 0.171
# Validation loss: 0.191
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['e', 'c', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['c', 'e', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['c', 'e', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 20/200
# Batch : 0/77
# Training Loss : 0.202
# Validation loss: 0.193
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['z', 'e', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['e', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['e', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 20/200
# Batch : 30/77
# Training Loss : 0.175
# Validation loss: 0.185
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['o', 'o', 'n', 's', '<PAD>', '<PAD>', '<PAD>']
# Target : ['n', 'o', 'o', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['o', 'o', 'o', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 20/200
# Batch : 60/77
# Training Loss : 0.157
# Validation loss: 0.176
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['z', 'e', 'k', 'h', 'u', 'z', 'b']
# Target : ['b', 'e', 'h', 'k', 'u', 'z', 'z', '<EOS>']
# Predict : ['a', 'e', 'h', 'k', 'u', 'z', 'z', '<EOS>']
#
# Epoch : 21/200
# Batch : 0/77
# Training Loss : 0.184
# Validation loss: 0.179
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['e', 'k', 'w', 'r', '<PAD>', '<PAD>', '<PAD>']
# Target : ['e', 'k', 'r', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['e', 'k', 'r', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 21/200
# Batch : 30/77
# Training Loss : 0.161
# Validation loss: 0.173
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['w', 'r', 'o', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['o', 'r', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['o', 'r', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 21/200
# Batch : 60/77
# Training Loss : 0.145
# Validation loss: 0.163
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['g', 'g', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['g', 'g', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['g', 'g', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 22/200
# Batch : 0/77
# Training Loss : 0.168
# Validation loss: 0.168
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['q', 'h', 'u', 'y', 'r', 'u', '<PAD>']
# Target : ['h', 'q', 'r', 'u', 'u', 'y', '<EOS>', '<PAD>']
# Predict : ['h', 'r', 'r', 'u', 'u', 'y', '<EOS>', '<PAD>']
#
# Epoch : 22/200
# Batch : 30/77
# Training Loss : 0.148
# Validation loss: 0.161
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['v', 'p', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['p', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['p', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 22/200
# Batch : 60/77
# Training Loss : 0.133
# Validation loss: 0.151
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['o', 'f', 's', 't', 'f', 'l', '<PAD>']
# Target : ['f', 'f', 'l', 'o', 's', 't', '<EOS>', '<PAD>']
# Predict : ['f', 'f', 'l', 'o', 's', 't', '<EOS>', '<PAD>']
#
# Epoch : 23/200
# Batch : 0/77
# Training Loss : 0.155
# Validation loss: 0.157
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['l', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['l', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['l', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 23/200
# Batch : 30/77
# Training Loss : 0.137
# Validation loss: 0.150
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['n', 'k', 'i', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['i', 'k', 'n', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['i', 'k', 'n', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 23/200
# Batch : 60/77
# Training Loss : 0.124
# Validation loss: 0.141
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['p', 'q', 's', 'r', 't', 'y', '<PAD>']
# Target : ['p', 'q', 'r', 's', 't', 'y', '<EOS>', '<PAD>']
# Predict : ['p', 'q', 's', 't', 't', 'y', '<EOS>', '<PAD>']
# Epoch : 24/200
# Batch : 0/77
# Training Loss : 0.142
# Validation loss: 0.147
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['q', 'h', 'u', 'y', 'r', 'u', '<PAD>']
# Target : ['h', 'q', 'r', 'u', 'u', 'y', '<EOS>', '<PAD>']
# Predict : ['h', 'r', 'r', 'u', 'u', 'y', '<EOS>', '<PAD>']
#
# Epoch : 24/200
# Batch : 30/77
# Training Loss : 0.128
# Validation loss: 0.141
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['a', 'b', 'q', 'k', 'q', 'l', 'p']
# Target : ['a', 'b', 'k', 'l', 'p', 'q', 'q', '<EOS>']
# Predict : ['a', 'b', 'i', 'l', 'p', 'q', 'q', '<EOS>']
#
# Epoch : 24/200
# Batch : 60/77
# Training Loss : 0.115
# Validation loss: 0.131
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['a', 'y', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['a', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['a', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 25/200
# Batch : 0/77
# Training Loss : 0.130
# Validation loss: 0.136
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['p', 'r', 'u', 'h', 'c', 'j', '<PAD>']
# Target : ['c', 'h', 'j', 'p', 'r', 'u', '<EOS>', '<PAD>']
# Predict : ['c', 'h', 'j', 'p', 'r', 'u', '<EOS>', '<PAD>']
#
# Epoch : 25/200
# Batch : 30/77
# Training Loss : 0.121
# Validation loss: 0.135
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['f', 'm', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 'm', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 'm', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 25/200
# Batch : 60/77
# Training Loss : 0.107
# Validation loss: 0.121
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['b', 'c', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['b', 'c', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['b', 'c', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 26/200
# Batch : 0/77
# Training Loss : 0.120
# Validation loss: 0.126
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['z', 's', 'u', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['s', 'u', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['s', 'u', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 26/200
# Batch : 30/77
# Training Loss : 0.115
# Validation loss: 0.131
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['v', 'p', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['p', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['p', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 26/200
# Batch : 60/77
# Training Loss : 0.100
# Validation loss: 0.113
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['r', 't', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['r', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['r', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 27/200
# Batch : 0/77
# Training Loss : 0.111
# Validation loss: 0.118
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['r', 'r', 'i', 't', 'u', 'j', '<PAD>']
# Target : ['i', 'j', 'r', 'r', 't', 'u', '<EOS>', '<PAD>']
# Predict : ['i', 'k', 'r', 'r', 't', 'u', '<EOS>', '<PAD>']
#
# Epoch : 27/200
# Batch : 30/77
# Training Loss : 0.107
# Validation loss: 0.129
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['q', 'e', 't', 'm', 'u', 's', '<PAD>']
# Target : ['e', 'm', 'q', 's', 't', 'u', '<EOS>', '<PAD>']
# Predict : ['e', 'm', 'q', 's', 't', 'u', '<EOS>', '<PAD>']
#
# Epoch : 27/200
# Batch : 60/77
# Training Loss : 0.093
# Validation loss: 0.107
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['w', 'v', 's', 'm', 'd', '<PAD>', '<PAD>']
# Target : ['d', 'm', 's', 'v', 'w', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['d', 'm', 's', 'v', 'w', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 28/200
# Batch : 0/77
# Training Loss : 0.103
# Validation loss: 0.109
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['q', 'v', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['q', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['q', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 28/200
# Batch : 30/77
# Training Loss : 0.097
# Validation loss: 0.124
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['e', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['e', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['e', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 28/200
# Batch : 60/77
# Training Loss : 0.086
# Validation loss: 0.101
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['d', 'g', 'g', 'w', 'o', 'm', 'e']
# Target : ['d', 'e', 'g', 'g', 'm', 'o', 'w', '<EOS>']
# Predict : ['d', 'e', 'g', 'g', 'm', 'o', 'w', '<EOS>']
#
# Epoch : 29/200
# Batch : 0/77
# Training Loss : 0.096
# Validation loss: 0.101
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['f', 'r', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 'r', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 'r', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 29/200
# Batch : 30/77
# Training Loss : 0.091
# Validation loss: 0.109
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['s', 'b', 'g', 'x', 'y', 'i', 'p']
# Target : ['b', 'g', 'i', 'p', 's', 'x', 'y', '<EOS>']
# Predict : ['b', 'g', 'i', 'p', 's', 'x', 'y', '<EOS>']
#
# Epoch : 29/200
# Batch : 60/77
# Training Loss : 0.083
# Validation loss: 0.098
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['t', 'e', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['e', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['e', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 30/200
# Batch : 0/77
# Training Loss : 0.090
# Validation loss: 0.101
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['t', 'e', 'z', 't', 'q', '<PAD>', '<PAD>']
# Target : ['e', 'q', 't', 't', 'z', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['e', 'q', 't', 't', 'z', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 30/200
# Batch : 30/77
# Training Loss : 0.087
# Validation loss: 0.097
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['x', 't', 'o', 'm', 'h', 'q', '<PAD>']
# Target : ['h', 'm', 'o', 'q', 't', 'x', '<EOS>', '<PAD>']
# Predict : ['h', 'm', 'o', 'q', 't', 'x', '<EOS>', '<PAD>']
#
# Epoch : 30/200
# Batch : 60/77
# Training Loss : 0.077
# Validation loss: 0.093
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['p', 'q', 't', 'q', '<PAD>', '<PAD>', '<PAD>']
# Target : ['p', 'q', 'q', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['p', 'q', 'q', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 31/200
# Batch : 0/77
# Training Loss : 0.084
# Validation loss: 0.095
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['p', 'd', 'l', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['d', 'l', 'p', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['d', 'l', 'p', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 31/200
# Batch : 30/77
# Training Loss : 0.080
# Validation loss: 0.091
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['f', 'm', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 'm', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 'm', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 31/200
# Batch : 60/77
# Training Loss : 0.073
# Validation loss: 0.085
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['i', 'k', 'c', 'z', 'c', '<PAD>', '<PAD>']
# Target : ['c', 'c', 'i', 'k', 'z', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['c', 'c', 'i', 'k', 'z', '<EOS>', '<PAD>', '<PAD>']
# Epoch : 32/200
# Batch : 0/77
# Training Loss : 0.080
# Validation loss: 0.088
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['s', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['s', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['s', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 32/200
# Batch : 30/77
# Training Loss : 0.075
# Validation loss: 0.093
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['m', 'p', 'i', 'o', 'w', 'd', '<PAD>']
# Target : ['d', 'i', 'm', 'o', 'p', 'w', '<EOS>', '<PAD>']
# Predict : ['d', 'i', 'm', 'o', 'p', 'w', '<EOS>', '<PAD>']
#
# Epoch : 32/200
# Batch : 60/77
# Training Loss : 0.069
# Validation loss: 0.082
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['d', 'g', 'g', 'w', 'o', 'm', 'e']
# Target : ['d', 'e', 'g', 'g', 'm', 'o', 'w', '<EOS>']
# Predict : ['d', 'e', 'g', 'g', 'm', 'o', 'w', '<EOS>']
#
# Epoch : 33/200
# Batch : 0/77
# Training Loss : 0.076
# Validation loss: 0.084
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['z', 's', 'u', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['s', 'u', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['s', 'u', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 33/200
# Batch : 30/77
# Training Loss : 0.070
# Validation loss: 0.090
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['s', 'o', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['o', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['o', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 33/200
# Batch : 60/77
# Training Loss : 0.065
# Validation loss: 0.076
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['y', 's', 'f', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 's', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 's', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 34/200
# Batch : 0/77
# Training Loss : 0.072
# Validation loss: 0.081
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['l', 'a', 'a', 'f', 'f', 'u', 'g']
# Target : ['a', 'a', 'f', 'f', 'g', 'l', 'u', '<EOS>']
# Predict : ['a', 'a', 'f', 'f', 'g', 'l', 'u', '<EOS>']
#
# Epoch : 34/200
# Batch : 30/77
# Training Loss : 0.066
# Validation loss: 0.081
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['o', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['o', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['o', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 34/200
# Batch : 60/77
# Training Loss : 0.062
# Validation loss: 0.074
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['q', 'h', 'j', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['h', 'j', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['h', 'j', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 35/200
# Batch : 0/77
# Training Loss : 0.069
# Validation loss: 0.079
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['s', 'd', 'o', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['d', 'o', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['d', 'o', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 35/200
# Batch : 30/77
# Training Loss : 0.065
# Validation loss: 0.073
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['o', 't', 'a', 'i', 'h', 'i', 'd']
# Target : ['a', 'd', 'h', 'i', 'i', 'o', 't', '<EOS>']
# Predict : ['a', 'd', 'h', 'i', 'i', 'o', 't', '<EOS>']
#
# Epoch : 35/200
# Batch : 60/77
# Training Loss : 0.058
# Validation loss: 0.068
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['z', 'b', 'q', 'n', 'o', 'z', '<PAD>']
# Target : ['b', 'n', 'o', 'q', 'z', 'z', '<EOS>', '<PAD>']
# Predict : ['b', 'n', 'o', 'q', 'z', 'z', '<EOS>', '<PAD>']
#
# Epoch : 36/200
# Batch : 0/77
# Training Loss : 0.065
# Validation loss: 0.073
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['l', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['l', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['l', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 36/200
# Batch : 30/77
# Training Loss : 0.061
# Validation loss: 0.067
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['i', 'x', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['i', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['i', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 36/200
# Batch : 60/77
# Training Loss : 0.053
# Validation loss: 0.069
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['f', 'x', 'm', 'p', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 'm', 'p', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 'm', 'p', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 37/200
# Batch : 0/77
# Training Loss : 0.061
# Validation loss: 0.069
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['d', 'a', 'v', 'o', 'k', 'o', 'c']
# Target : ['a', 'c', 'd', 'k', 'o', 'o', 'v', '<EOS>']
# Predict : ['a', 'c', 'g', 'k', 'o', 'o', 'v', '<EOS>']
#
# Epoch : 37/200
# Batch : 30/77
# Training Loss : 0.058
# Validation loss: 0.064
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['i', 'h', 'f', 'o', 'o', '<PAD>', '<PAD>']
# Target : ['f', 'h', 'i', 'o', 'o', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['f', 'h', 'i', 'o', 'o', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 37/200
# Batch : 60/77
# Training Loss : 0.050
# Validation loss: 0.060
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['t', 'w', 'm', 'a', 'm', 'j', '<PAD>']
# Target : ['a', 'j', 'm', 'm', 't', 'w', '<EOS>', '<PAD>']
# Predict : ['a', 'j', 'm', 'm', 't', 'w', '<EOS>', '<PAD>']
#
# Epoch : 38/200
# Batch : 0/77
# Training Loss : 0.058
# Validation loss: 0.063
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['t', 'j', 'q', 'r', 'z', '<PAD>', '<PAD>']
# Target : ['j', 'q', 'r', 't', 'z', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['j', 'q', 'r', 't', 'z', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 38/200
# Batch : 30/77
# Training Loss : 0.055
# Validation loss: 0.059
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['r', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['r', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['r', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 38/200
# Batch : 60/77
# Training Loss : 0.047
# Validation loss: 0.057
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['h', 'e', 'k', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['e', 'h', 'k', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['e', 'h', 'k', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 39/200
# Batch : 0/77
# Training Loss : 0.055
# Validation loss: 0.060
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['h', 's', 't', 'm', 'q', 'q', 'c']
# Target : ['c', 'h', 'm', 'q', 'q', 's', 't', '<EOS>']
# Predict : ['c', 'h', 'm', 'q', 'q', 's', 't', '<EOS>']
#
# Epoch : 39/200
# Batch : 30/77
# Training Loss : 0.052
# Validation loss: 0.055
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['m', 'q', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['m', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['m', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 39/200
# Batch : 60/77
# Training Loss : 0.045
# Validation loss: 0.053
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['u', 'v', 'y', 'd', 'r', 'z', '<PAD>']
# Target : ['d', 'r', 'u', 'v', 'y', 'z', '<EOS>', '<PAD>']
# Predict : ['d', 'r', 'u', 'v', 'y', 'z', '<EOS>', '<PAD>']
# Epoch : 40/200
# Batch : 0/77
# Training Loss : 0.052
# Validation loss: 0.057
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['l', 'a', 'a', 'f', 'f', 'u', 'g']
# Target : ['a', 'a', 'f', 'f', 'g', 'l', 'u', '<EOS>']
# Predict : ['a', 'a', 'f', 'f', 'g', 'l', 'u', '<EOS>']
#
# Epoch : 40/200
# Batch : 30/77
# Training Loss : 0.050
# Validation loss: 0.051
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['m', 'q', 'm', 'w', 'u', 'l', '<PAD>']
# Target : ['l', 'm', 'm', 'q', 'u', 'w', '<EOS>', '<PAD>']
# Predict : ['k', 'm', 'm', 'q', 'u', 'w', '<EOS>', '<PAD>']
#
# Epoch : 40/200
# Batch : 60/77
# Training Loss : 0.042
# Validation loss: 0.049
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['t', 'z', 'i', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['i', 't', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['i', 't', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 41/200
# Batch : 0/77
# Training Loss : 0.049
# Validation loss: 0.057
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['p', 'h', 'w', 'y', 'c', 'r', 'c']
# Target : ['c', 'c', 'h', 'p', 'r', 'w', 'y', '<EOS>']
# Predict : ['c', 'c', 'h', 'p', 'r', 'w', 'y', '<EOS>']
#
# Epoch : 41/200
# Batch : 30/77
# Training Loss : 0.048
# Validation loss: 0.048
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['z', 'g', 'l', 'h', 'w', 'd', '<PAD>']
# Target : ['d', 'g', 'h', 'l', 'w', 'z', '<EOS>', '<PAD>']
# Predict : ['d', 'g', 'h', 'l', 'w', 'z', '<EOS>', '<PAD>']
#
# Epoch : 41/200
# Batch : 60/77
# Training Loss : 0.041
# Validation loss: 0.045
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['f', 'x', 'm', 'p', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 'm', 'p', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 'm', 'p', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 42/200
# Batch : 0/77
# Training Loss : 0.048
# Validation loss: 0.053
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['s', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['s', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['s', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 42/200
# Batch : 30/77
# Training Loss : 0.045
# Validation loss: 0.045
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['q', 'e', 't', 'm', 'u', 's', '<PAD>']
# Target : ['e', 'm', 'q', 's', 't', 'u', '<EOS>', '<PAD>']
# Predict : ['e', 'm', 'q', 's', 't', 'u', '<EOS>', '<PAD>']
#
# Epoch : 42/200
# Batch : 60/77
# Training Loss : 0.039
# Validation loss: 0.043
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['t', 'w', 'm', 'a', 'm', 'j', '<PAD>']
# Target : ['a', 'j', 'm', 'm', 't', 'w', '<EOS>', '<PAD>']
# Predict : ['a', 'j', 'm', 'm', 't', 'w', '<EOS>', '<PAD>']
#
# Epoch : 43/200
# Batch : 0/77
# Training Loss : 0.046
# Validation loss: 0.054
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['h', 'v', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['h', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['h', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 43/200
# Batch : 30/77
# Training Loss : 0.043
# Validation loss: 0.044
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['m', 'p', 'i', 'o', 'w', 'd', '<PAD>']
# Target : ['d', 'i', 'm', 'o', 'p', 'w', '<EOS>', '<PAD>']
# Predict : ['d', 'i', 'm', 'o', 'p', 'w', '<EOS>', '<PAD>']
#
# Epoch : 43/200
# Batch : 60/77
# Training Loss : 0.038
# Validation loss: 0.043
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['d', 'g', 'g', 'w', 'o', 'm', 'e']
# Target : ['d', 'e', 'g', 'g', 'm', 'o', 'w', '<EOS>']
# Predict : ['d', 'e', 'g', 'g', 'm', 'o', 'w', '<EOS>']
#
# Epoch : 44/200
# Batch : 0/77
# Training Loss : 0.042
# Validation loss: 0.058
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['s', 'a', 'j', 'f', '<PAD>', '<PAD>', '<PAD>']
# Target : ['a', 'f', 'j', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['a', 'f', 'j', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 44/200
# Batch : 30/77
# Training Loss : 0.044
# Validation loss: 0.045
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['y', 't', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['t', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['t', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 44/200
# Batch : 60/77
# Training Loss : 0.038
# Validation loss: 0.045
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['s', 'v', 'h', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['h', 's', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['h', 's', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 45/200
# Batch : 0/77
# Training Loss : 0.041
# Validation loss: 0.053
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['w', 'w', 'm', 'h', 's', 'g', '<PAD>']
# Target : ['g', 'h', 'm', 's', 'w', 'w', '<EOS>', '<PAD>']
# Predict : ['g', 'h', 'm', 's', 'w', 'w', '<EOS>', '<PAD>']
#
# Epoch : 45/200
# Batch : 30/77
# Training Loss : 0.043
# Validation loss: 0.042
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['r', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['r', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['r', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 45/200
# Batch : 60/77
# Training Loss : 0.034
# Validation loss: 0.040
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['b', 'z', 'e', 'p', 'j', 'v', '<PAD>']
# ...
# Validation loss: 0.041
# stop_early : 4
# coin_tossing : [False False False False False False False False]
# Source : ['d', 'g', 'g', 'w', 'o', 'm', 'e']
# Target : ['d', 'e', 'g', 'g', 'm', 'o', 'w', '<EOS>']
# Predict : ['d', 'e', 'g', 'g', 'm', 'o', 'w', '<EOS>']
#
# Epoch : 100/200
# Batch : 0/77
# Training Loss : 0.022
# Validation loss: 0.039
# stop_early : 5
# coin_tossing : [False False False False False False False False]
# Source : ['l', 'a', 'm', 'v', '<PAD>', '<PAD>', '<PAD>']
# Target : ['a', 'l', 'm', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['a', 'l', 'm', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 100/200
# Batch : 30/77
# Training Loss : 0.024
# Validation loss: 0.039
# stop_early : 5
# coin_tossing : [False False False False False False False False]
# Source : ['f', 'm', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 'm', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 'm', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 100/200
# Batch : 60/77
# Training Loss : 0.023
# Validation loss: 0.037
# stop_early : 5
# coin_tossing : [False False False False False False False False]
# Source : ['c', 'm', 'u', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['c', 'm', 'u', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['c', 'm', 'u', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 101/200
# Batch : 0/77
# Training Loss : 0.020
# Validation loss: 0.036
# stop_early : 6
# coin_tossing : [False False False False False False False False]
# Source : ['s', 'd', 'o', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['d', 'o', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['d', 'o', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 101/200
# Batch : 30/77
# Training Loss : 0.022
# Validation loss: 0.036
# stop_early : 6
# coin_tossing : [False False False False False False False False]
# Source : ['s', 'o', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['o', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['o', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 101/200
# Batch : 60/77
# Training Loss : 0.021
# Validation loss: 0.034
# stop_early : 6
# coin_tossing : [False False False False False False False False]
# Source : ['h', 'e', 'k', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['e', 'h', 'k', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['e', 'h', 'k', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 102/200
# Batch : 0/77
# Training Loss : 0.018
# Validation loss: 0.034
# stop_early : 7
# coin_tossing : [False False False False False False False False]
# Source : ['s', 'b', 'g', 'e', 'e', 'f', 'f']
# Target : ['b', 'e', 'e', 'f', 'f', 'g', 's', '<EOS>']
# Predict : ['b', 'e', 'e', 'f', 'f', 'g', 's', '<EOS>']
#
# Epoch : 102/200
# Batch : 30/77
# Training Loss : 0.020
# Validation loss: 0.034
# stop_early : 7
# coin_tossing : [False False False False False False False False]
# Source : ['s', 'w', 'l', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['l', 's', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['l', 's', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 102/200
# Batch : 60/77
# Training Loss : 0.020
# Validation loss: 0.031
# stop_early : 7
# coin_tossing : [False False False False False False False False]
# Source : ['f', 'i', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 'i', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 'i', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 103/200
# Batch : 0/77
# Training Loss : 0.017
# Validation loss: 0.032
# stop_early : 8
# coin_tossing : [False False False False False False False False]
# Source : ['t', 'j', 'e', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['e', 'j', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['e', 'j', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 103/200
# Batch : 30/77
# Training Loss : 0.018
# Validation loss: 0.032
# stop_early : 8
# coin_tossing : [False False False False False False False False]
# Source : ['i', 'c', 'g', 'f', 'l', 'e', 'i']
# Target : ['c', 'e', 'f', 'g', 'i', 'i', 'l', '<EOS>']
# Predict : ['c', 'e', 'f', 'g', 'i', 'i', 'l', '<EOS>']
#
# Epoch : 103/200
# Batch : 60/77
# Training Loss : 0.018
# Validation loss: 0.029
# stop_early : 8
# coin_tossing : [False False False False False False False False]
# Source : ['t', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['t', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['t', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 104/200
# Batch : 0/77
# Training Loss : 0.016
# Validation loss: 0.030
# stop_early : 9
# coin_tossing : [False False False False False False False False]
# Source : ['t', 'j', 'e', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['e', 'j', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['e', 'j', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Epoch : 104/200
# Batch : 30/77
# Training Loss : 0.017
# Validation loss: 0.030
# stop_early : 9
# coin_tossing : [False False False False False False False False]
# Source : ['r', 'y', 'j', 'w', '<PAD>', '<PAD>', '<PAD>']
# Target : ['j', 'r', 'w', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['j', 'r', 'w', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 104/200
# Batch : 60/77
# Training Loss : 0.017
# Validation loss: 0.028
# stop_early : 9
# coin_tossing : [False False False False False False False False]
# Source : ['l', 'k', 's', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['k', 'l', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['k', 'l', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 105/200
# Batch : 0/77
# Training Loss : 0.014
# Validation loss: 0.029
# stop_early : 10
# coin_tossing : [False False False False False False False False]
# Source : ['r', 'r', 'i', 't', 'u', 'j', '<PAD>']
# Target : ['i', 'j', 'r', 'r', 't', 'u', '<EOS>', '<PAD>']
# Predict : ['i', 'j', 'r', 'r', 't', 'u', '<EOS>', '<PAD>']
#
# Epoch : 105/200
# Batch : 30/77
# Training Loss : 0.016
# Validation loss: 0.028
# stop_early : 10
# coin_tossing : [False False False False False False False False]
# Source : ['y', 'z', 's', 'f', 'p', 'k', '<PAD>']
# Target : ['f', 'k', 'p', 's', 'y', 'z', '<EOS>', '<PAD>']
# Predict : ['f', 'k', 'p', 's', 'y', 'z', '<EOS>', '<PAD>']
#
# Epoch : 105/200
# Batch : 60/77
# Training Loss : 0.015
# Validation loss: 0.026
# stop_early : 10
# coin_tossing : [False False False False False False False False]
# Source : ['j', 'd', 't', 'i', 's', 'w', 'n']
# Target : ['d', 'i', 'j', 'n', 's', 't', 'w', '<EOS>']
# Predict : ['d', 'i', 'j', 'n', 's', 't', 'w', '<EOS>']
#
# Epoch : 106/200
# Batch : 0/77
# Training Loss : 0.014
# Validation loss: 0.027
# stop_early : 11
# coin_tossing : [False False False False False False False False]
# Source : ['t', 'd', 'y', 'b', '<PAD>', '<PAD>', '<PAD>']
# Target : ['b', 'd', 't', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['b', 'd', 't', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 106/200
# Batch : 30/77
# Training Loss : 0.015
# Validation loss: 0.026
# stop_early : 11
# coin_tossing : [False False False False False False False False]
# Source : ['l', 'k', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['k', 'l', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['k', 'l', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 106/200
# Batch : 60/77
# Training Loss : 0.014
# Validation loss: 0.025
# stop_early : 11
# coin_tossing : [False False False False False False False False]
# Source : ['z', 'w', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['w', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['w', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 107/200
# Batch : 0/77
# Training Loss : 0.013
# Validation loss: 0.026
# stop_early : 12
# coin_tossing : [False False False False False False False False]
# Source : ['w', 'x', 'x', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['w', 'x', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['w', 'x', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 107/200
# Batch : 30/77
# Training Loss : 0.014
# Validation loss: 0.025
# stop_early : 12
# coin_tossing : [False False False False False False False False]
# Source : ['m', 'm', 'e', 't', 'm', 'z', '<PAD>']
# Target : ['e', 'm', 'm', 'm', 't', 'z', '<EOS>', '<PAD>']
# Predict : ['e', 'm', 'm', 'm', 't', 'z', '<EOS>', '<PAD>']
#
# Epoch : 107/200
# Batch : 60/77
# Training Loss : 0.013
# Validation loss: 0.024
# stop_early : 12
# coin_tossing : [False False False False False False False False]
# Source : ['l', 'v', 'a', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['a', 'l', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['a', 'l', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 108/200
# Batch : 0/77
# Training Loss : 0.012
# Validation loss: 0.025
# stop_early : 13
# coin_tossing : [False False False False False False False False]
# Source : ['l', 'g', 'y', 'l', 'o', 'p', 'k']
# Target : ['g', 'k', 'l', 'l', 'o', 'p', 'y', '<EOS>']
# Predict : ['g', 'k', 'l', 'l', 'o', 'p', 'y', '<EOS>']
#
# Epoch : 108/200
# Batch : 30/77
# Training Loss : 0.013
# Validation loss: 0.024
# stop_early : 13
# coin_tossing : [False False False False False False False False]
# Source : ['a', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['a', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['a', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 108/200
# Batch : 60/77
# Training Loss : 0.013
# Validation loss: 0.022
# stop_early : 13
# coin_tossing : [False False False False False False False False]
# Source : ['g', 'a', 'u', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['a', 'g', 'u', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['a', 'g', 'u', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 109/200
# Batch : 0/77
# Training Loss : 0.011
# Validation loss: 0.024
# stop_early : 14
# coin_tossing : [False False False False False False False False]
# Source : ['v', 'k', 'q', 'm', '<PAD>', '<PAD>', '<PAD>']
# Target : ['k', 'm', 'q', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['k', 'm', 'q', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 109/200
# Batch : 30/77
# Training Loss : 0.012
# Validation loss: 0.023
# stop_early : 14
# coin_tossing : [False False False False False False False False]
# Source : ['o', 't', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['o', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['o', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 109/200
# Batch : 60/77
# Training Loss : 0.012
# Validation loss: 0.021
# stop_early : 14
# coin_tossing : [False False False False False False False False]
# Source : ['a', 'f', 'e', 'q', 'b', '<PAD>', '<PAD>']
# Target : ['a', 'b', 'e', 'f', 'q', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['a', 'b', 'e', 'f', 'q', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 110/200
# Batch : 0/77
# Training Loss : 0.011
# Validation loss: 0.023
# stop_early : 15
# coin_tossing : [False False False False False False False False]
# Source : ['p', 't', 'g', 'f', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 'g', 'p', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 'g', 'p', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 110/200
# Batch : 30/77
# Training Loss : 0.012
# Validation loss: 0.022
# stop_early : 15
# coin_tossing : [False False False False False False False False]
# Source : ['a', 'w', 'q', 'i', 'h', 'f', '<PAD>']
# Target : ['a', 'f', 'h', 'i', 'q', 'w', '<EOS>', '<PAD>']
# Predict : ['a', 'f', 'h', 'i', 'q', 'w', '<EOS>', '<PAD>']
#
# Epoch : 110/200
# Batch : 60/77
# Training Loss : 0.011
# Validation loss: 0.020
# stop_early : 15
# coin_tossing : [False False False False False False False False]
# Source : ['t', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['t', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['t', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 111/200
# Batch : 0/77
# Training Loss : 0.010
# Validation loss: 0.022
# stop_early : 16
# coin_tossing : [False False False False False False False False]
# Source : ['q', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['q', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['q', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 111/200
# Batch : 30/77
# Training Loss : 0.011
# Validation loss: 0.021
# stop_early : 16
# coin_tossing : [False False False False False False False False]
# Source : ['x', 'f', 'b', 'y', 'v', 'o', '<PAD>']
# Target : ['b', 'f', 'o', 'v', 'x', 'y', '<EOS>', '<PAD>']
# Predict : ['b', 'f', 'o', 'v', 'x', 'y', '<EOS>', '<PAD>']
#
# Epoch : 111/200
# Batch : 60/77
# Training Loss : 0.010
# Validation loss: 0.019
# stop_early : 16
# coin_tossing : [False False False False False False False False]
# Source : ['e', 'y', 'e', 'l', 't', 'p', '<PAD>']
# Target : ['e', 'e', 'l', 'p', 't', 'y', '<EOS>', '<PAD>']
# Predict : ['e', 'e', 'l', 'p', 't', 'y', '<EOS>', '<PAD>']
#
# Epoch : 112/200
# Batch : 0/77
# Training Loss : 0.010
# Validation loss: 0.021
# stop_early : 17
# coin_tossing : [False False False False False False False False]
# Source : ['k', 'a', 'l', 'e', 'y', 'p', '<PAD>']
# Target : ['a', 'e', 'k', 'l', 'p', 'y', '<EOS>', '<PAD>']
# Predict : ['a', 'e', 'k', 'l', 'p', 'y', '<EOS>', '<PAD>']
# Epoch : 112/200
# Batch : 30/77
# Training Loss : 0.010
# Validation loss: 0.020
# stop_early : 17
# coin_tossing : [False False False False False False False False]
# Source : ['p', 'x', 'i', 'f', 'k', 'i', '<PAD>']
# Target : ['f', 'i', 'i', 'k', 'p', 'x', '<EOS>', '<PAD>']
# Predict : ['f', 'i', 'i', 'k', 'p', 'x', '<EOS>', '<PAD>']
#
# Epoch : 112/200
# Batch : 60/77
# Training Loss : 0.010
# Validation loss: 0.018
# stop_early : 17
# coin_tossing : [False False False False False False False False]
# Source : ['b', 'i', 'g', 'n', 'd', 'n', 'c']
# Target : ['b', 'c', 'd', 'g', 'i', 'n', 'n', '<EOS>']
# Predict : ['b', 'c', 'd', 'g', 'i', 'n', 'n', '<EOS>']
#
# Epoch : 113/200
# Batch : 0/77
# Training Loss : 0.010
# Validation loss: 0.020
# stop_early : 18
# coin_tossing : [False False False False False False False False]
# Source : ['p', 'r', 'v', 's', 'y', '<PAD>', '<PAD>']
# Target : ['p', 'r', 's', 'v', 'y', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['p', 'r', 's', 'v', 'y', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 113/200
# Batch : 30/77
# Training Loss : 0.010
# Validation loss: 0.019
# stop_early : 18
# coin_tossing : [False False False False False False False False]
# Source : ['y', 'z', 's', 'f', 'p', 'k', '<PAD>']
# Target : ['f', 'k', 'p', 's', 'y', 'z', '<EOS>', '<PAD>']
# Predict : ['f', 'k', 'p', 's', 'y', 'z', '<EOS>', '<PAD>']
#
# Epoch : 113/200
# Batch : 60/77
# Training Loss : 0.009
# Validation loss: 0.017
# stop_early : 18
# coin_tossing : [False False False False False False False False]
# Source : ['e', 'c', 'n', 'h', 't', 'm', 'v']
# Target : ['c', 'e', 'h', 'm', 'n', 't', 'v', '<EOS>']
# Predict : ['c', 'e', 'h', 'm', 'n', 't', 'v', '<EOS>']
#
# Epoch : 114/200
# Batch : 0/77
# Training Loss : 0.009
# Validation loss: 0.019
# stop_early : 19
# coin_tossing : [False False False False False False False False]
# Source : ['j', 'p', 'j', 'y', 'c', 'f', 'z']
# Target : ['c', 'f', 'j', 'j', 'p', 'y', 'z', '<EOS>']
# Predict : ['c', 'f', 'j', 'j', 'p', 'y', 'z', '<EOS>']
#
# Epoch : 114/200
# Batch : 30/77
# Training Loss : 0.009
# Validation loss: 0.018
# stop_early : 19
# coin_tossing : [False False False False False False False False]
# Source : ['s', 'o', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['o', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['o', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 114/200
# Batch : 60/77
# Training Loss : 0.009
# Validation loss: 0.016
# stop_early : 19
# coin_tossing : [False False False False False False False False]
# Source : ['x', 'q', 'q', 'i', 'k', 'u', 't']
# Target : ['i', 'k', 'q', 'q', 't', 'u', 'x', '<EOS>']
# Predict : ['i', 'k', 'q', 'q', 't', 'u', 'x', '<EOS>']
#
# Model Trained and Saved

# %% [markdown]
# ## Testing

# %%
import os    
sess = tf.Session()
new_saver = tf.train.import_meta_graph(os.path.join('trained_model/save_net.meta'))
new_saver.restore(sess, tf.train.latest_checkpoint(os.path.join('trained_model')))

graph = tf.get_default_graph()
input_data = graph.get_tensor_by_name('inputs:0')
targets = graph.get_tensor_by_name('targets:0')
predicting_logits = graph.get_tensor_by_name('predictions:0')
from_model_or_target = graph.get_tensor_by_name('on_train:0')

input_word = 'common'

test_source = [] 
for letter in input_word:
    if letter not in source_letter_to_int.keys():
        test_source.append(source_letter_to_int['<UNK>'])
    else:
        test_source.append(source_letter_to_int[letter])
        
# 輸入的句子的長度是固定source_max_length，所以補source_letter_to_int['<PAD>']到長度為source_max_length
while len(test_source) < source_max_length:
    test_source.append(source_letter_to_int['<PAD>'])
test_source = [test_source] * batch_size   
        
# test_target輸入的值可以隨便選，只要長度為target_max_length即可    
test_target = [0 for _ in range(0 , target_max_length)] 
test_target = [test_target] * batch_size

test_source = np.array(test_source)
test_target = np.array(test_target)
answer = sess.run(predicting_logits , feed_dict = {input_data : test_source ,
                                                   targets : test_target ,
                                                   from_model_or_target : coin_tossing})

answer = answer[0 , :]
answer_to_letter = []
for num in answer:
    answer_to_letter.append(target_int_to_letter[num])
print(answer_to_letter)
# Out:
# INFO:tensorflow:Restoring parameters from trained_model\save_net
# ['c', 'm', 'm', 'n', 'o', 'o', '<EOS>', '<PAD>']
