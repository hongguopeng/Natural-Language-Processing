# %% [markdown]
# # Seq2Seq
# 實現基礎版的Seq2Seq，輸入一個英文單字，模型將輸出一個對字母排序後的單字
# <br>輸入 : hello
# <br>輸出 : ehllo

# %% [markdown]
# 本程式試著不使用Tensorflow所提供的Helper指令，完成Scheduled Sampling<br>
# Scheduled Sampling是一種解決訓練和生成時輸入數據分布不一致的方法<br>
#
# 在一般的Seq2Seq模型的inference階段中，如果Sequence中在t時刻中產生錯誤的值，在t時刻之後的輸入狀態將會受到影響，而該誤差會隨著生成過程不斷向後累積；而Scheduled Sampling以一定概率將Decoder自己產生的值作為Decoder端的輸入，這樣即使前面產生錯誤的值，其目標仍然是最大化真實目標序列的概率，模型會朝著正確的方向進<br>
#
# 在訓練早期Scheduled Sampling主要使用target中的真實值作為Decoder端的輸入，可以將模型從隨機初始化的狀態快速引導至一個合理的狀態；隨著訓練的進行，該方法會逐漸更多地使用Decoder自己產生的值作為Decoder端的輸入，以解決數據分布不一致的問題<br>

# %% [markdown]
# <img src="3_scheduled_sampling_不使用helper指令_version_2.jpg" style="width:1240px;height:600px;float:middle">
# 以上為Decoder端的計算流程

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import time
import copy
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# %% [markdown]
# # 讀取數據

# %%
f = open('data/letters_source.txt', 'r', encoding = 'utf-8')
source_data = f.read()

f = open('data/letters_target.txt', 'r', encoding = 'utf-8')
target_data = f.read()

# %% [markdown]
# # 數據預處理

# %%
def extract_character_vocab(data):
    
    special_words = ['<PAD>' , '<UNK>' , '<GO>' , '<EOS>']
    
    words = []
    for line in data.split('\n'):
        for character in line:
            if character not in words:
                words.append(character)

    # 將四個特殊字加入詞庫       
    int_to_vocab = {idx: word for idx , word in enumerate(special_words + words)}
    vocab_to_int = dict(zip(int_to_vocab.values() , int_to_vocab.keys()))

    return int_to_vocab, vocab_to_int

# %%
source_int_to_letter , source_letter_to_int = extract_character_vocab(source_data)
target_int_to_letter , target_letter_to_int = extract_character_vocab(target_data)

# 將所有字母轉換成index
source_int = []
for line in source_data.split('\n'):
    temp = []
    for letter in line:
        temp.append(source_letter_to_int[letter])
    source_int.append(temp)    
        
target_int = []
for line in target_data.split('\n'):
    temp = []
    for letter in line:
        temp.append(target_letter_to_int[letter])
    temp = temp + [target_letter_to_int['<EOS>']]
    target_int.append(temp)

# %%
# 決定source_int與target_int中的最大長度
# 因為後面的decoder的rnn不是使用tf.nn.dynamic_rnn，無法使用動態長度的功能，所以在這裡就要決定每個batch的長度
source_max_length , target_max_length = 0 , 0  
for vob_source , vob_target in zip(source_int , target_int):
    if len(vob_source) > source_max_length:
        source_max_length = len(vob_source)    
    if len(vob_target) > target_max_length:
        target_max_length = len(vob_target)  

# 分別對source_int與target_int_pad 補source_letter_to_int['<PAD>']與target_letter_to_int['<PAD>']到最大長度  
source_int_pad , target_int_pad = [] , []
for i_source , j_target in zip(range(len(source_int)) , range(len(target_int))):
    temp_source = source_int[i_source].copy()
    while len(temp_source) < source_max_length:
        temp_source.append(source_letter_to_int['<PAD>']) 
    source_int_pad.append(temp_source)
    
    temp_target = target_int[j_target].copy()
    while len(temp_target) < target_max_length:
        temp_target.append(target_letter_to_int['<PAD>']) 
    target_int_pad.append(temp_target)       

source_int_pad = np.array(source_int_pad)
target_int_pad = np.array(target_int_pad)

# %%
# 超參數
# Number of Epochs
epochs = 200
# Batch Size
batch_size = 128
# RNN Size
rnn_hidden_unit = 50
# Number of Layers
num_layers = 1
# Embedding Size
encoding_embedding_size = 15
decoding_embedding_size = rnn_hidden_unit
# Learning Rate
learning_rate = 0.001
source_vocab_size = len(source_int_to_letter)
target_vocab_size = len(target_int_to_letter)

# %% [markdown]
# # Build Model

# %% [markdown]
# ## 輸入層

# %%
input_data = tf.placeholder(tf.int32, [None , source_max_length] , name = 'inputs')
targets = tf.placeholder(tf.int32, [None , target_max_length] , name = 'targets')
targets_onehot = tf.one_hot(tf.reshape(targets , [-1]) , depth = target_vocab_size)
lr = tf.placeholder(tf.float32 , name = 'learning_rate')

# 決定到底是"t-1階段的輸出"還是"target中的真實答案"，當作t階段的輸入
from_model_or_target = tf.placeholder(tf.bool , [target_max_length , ] , name = 'from_model_or_target')

# %% [markdown]
# ## Encoder

# %% [markdown]
# 需要對source數據進行embedding，再傳入Decoder中的RNN

# %%
# input_data: 輸入tensor
# rnn_hidden_unit: rnn隱層結點數量
# num_layers: rnn cell的層數
# source_sequence_length: source數據的序列長度
# source_vocab_size: source數據的詞庫大小
# encoding_embedding_size: embedding的向量維度

# Encoder embedding
'''
encoder_embed_input = tf.contrib.layers.embed_sequence(input_data , source_vocab_size , encoding_embedding_size) 
                                                  ⇕ 相當於
encoder_embeddings = tf.Variable(tf.random_uniform([source_vocab_size , encoding_embedding_size]))
encoder_embed_input = tf.nn.embedding_lookup(encoder_embeddings , input_data)

若懶得寫兩行程式可以直接用tf.contrib.layers.embed_sequence這個函數
介紹 : https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence
'''
encoder_embeddings = tf.Variable(tf.random_uniform([source_vocab_size , encoding_embedding_size]))
encoder_embed_input = tf.nn.embedding_lookup(encoder_embeddings , input_data)


def get_lstm_cell(rnn_hidden_unit):
    lstm_cell = tf.contrib.rnn.LSTMCell(rnn_hidden_unit, 
                                        initializer = tf.random_uniform_initializer(-0.1 , 0.1))
    return lstm_cell

with tf.variable_scope('encoder'):   
    encoder_cell = tf.contrib.rnn.MultiRNNCell([get_lstm_cell(rnn_hidden_unit) for _ in range(num_layers)])
    
    encoder_output, encoder_state = tf.nn.dynamic_rnn(encoder_cell , 
                                                      encoder_embed_input, 
                                                      dtype = tf.float32)

# %% [markdown]
# ## Decoder

# %%
# 預處理後的decoder輸入
# 在batch中每一筆data最前面加上<GO>，並移除最後一個字，所以每一筆data的詞的數目並無改變
# cut掉最後一個字
# ending = tf.strided_slice(targets , [0, 0] , [batch_size, -1] , [1, 1]) # 等同於 ending = tf.identity(targets[: , 0:-1])
ending = tf.identity(targets[: , 0:-1])
decoder_input = tf.concat([tf.fill([batch_size, 1] , target_letter_to_int['<GO>']) , ending] , axis = 1)

# %%
# decoding_embedding_size: embedding的向量維度
# num_layers: rnn cell的層數
# rnn_size: RNN單元的隱層結點數量
# encoder_state: encoder端編碼的狀態向量
# decoder_input: decoder端輸入

# 1. Embedding
decoder_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
decoder_embed_input = tf.nn.embedding_lookup(decoder_embeddings , decoder_input)

with tf.variable_scope('decoder'):
    # 2. 建造Decoder中的RNN單元
    decoder_cell = tf.contrib.rnn.MultiRNNCell([get_lstm_cell(rnn_hidden_unit) for _ in range(num_layers)])
    state = encoder_state 
    outputs  = []
    for time_step in range(0 , target_max_length):
        if time_step > 0: tf.get_variable_scope().reuse_variables()
        weights = tf.get_variable(initializer = tf.truncated_normal([rnn_hidden_unit , target_vocab_size] , mean = 0.01 , stddev = 0.1) , name = 'weights_decoder')
        biases = tf.get_variable(initializer = tf.zeros([1 , target_vocab_size]) + 0.0001 , name = 'biases_decoder')
        
        # 在訓練的過程中，除了time_step為0以外，每一個time_step都投擲硬幣決定
        # 要用decoder_embed_input[: , time_step , :](target中的真實答案)，還是mlstm_cell_output(machine自己產生的output)，輸入decoder_cell
        # 正面代表當前時刻decoder_cell要吃decoder_embed_input[: , time_step , :](target中的真實答案)
        # 反面代表當前時刻decoder_cell要吃上一個時刻decoder_cell的輸出，選取最大機率的對應詞，最後再經過embedding_lookup選取該詞的對應詞向量
        # 也就是coin tossing為[True , True , True , True , True , True , True , True]會逐漸變為[Faslse , Faslse , Faslse , Faslse , Faslse , Faslse , Faslse , Faslse]
        # 前幾個epoch會有很大的機率擲出正面，但隨著訓練的過程擲出反面的機率會越來越大
        # 在後面的步驟會調節擲出正反面的機率
        if time_step == 0: 
            input_to_decoder = decoder_embed_input[: , 0 , :]
            mlstm_cell_output , state = decoder_cell(input_to_decoder , state)
            output = tf.matmul(mlstm_cell_output , weights) + biases
            outputs.append(output)
                
        elif time_step > 0:
            def from_target():
                input_to_decoder = decoder_embed_input[: , time_step , :]
                h_output , h_state = decoder_cell(input_to_decoder , state)
                return h_output , h_state

            def form_model():
                input_to_decoder = tf.argmax(output , axis = 1)
                input_to_decoder = tf.nn.embedding_lookup(decoder_embeddings , input_to_decoder)
                h_output , h_state = decoder_cell(input_to_decoder , state)
                return h_output , h_state

            mlstm_cell_output , state = tf.cond(from_model_or_target[time_step] ,
                                                from_target ,
                                                form_model)

            output = tf.matmul(mlstm_cell_output , weights) + biases
            outputs.append(output)

# %%
outputs_ = tf.transpose(tf.convert_to_tensor(outputs) , [1 , 0 , 2])    
logits = tf.reshape(outputs_ , [-1 , target_vocab_size])

# predicting_logits與訓練無關，純粹只是要看結果
predicting_logits = tf.nn.softmax(logits)   
predicting_logits = tf.argmax(predicting_logits , axis = 1)
predicting_logits = tf.reshape(predicting_logits , [batch_size , -1] , name = 'predictions')

# %%
# Loss function
loss = tf.nn.softmax_cross_entropy_with_logits(labels = targets_onehot , logits = logits)
total_loss = tf.reduce_mean(loss)

# Optimizer
optimizer = tf.train.AdamOptimizer(lr)

# Gradient Clipping
gradients = optimizer.compute_gradients(total_loss)
capped_gradients = [(tf.clip_by_value(grad, -5. , 5.), var) for grad, var in gradients if grad is not None]
train_op = optimizer.apply_gradients(capped_gradients)
# Out:
# WARNING:tensorflow:From <ipython-input-12-0dda0281734f>:2: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
# C:\Users\peng\Anaconda3\lib\site-packages\tensorflow\python\ops\gradients_impl.py:108: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %%
# 將數據集分割為train和validation
train_source = source_int_pad[batch_size:]
train_target = target_int_pad[batch_size:]
# 留出一個batch進行驗證
valid_source = source_int_pad[:batch_size]
valid_target = target_int_pad[:batch_size]

# %% [markdown]
# ## Training

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

prob = 1e-3
alpha = 1.075
stop_early = 0
for epoch_i in range(0 , epochs):
    
    # 在每進行一個epoch前，把每個batch的index先決定出來
    batch_index = []
    temp = []
    count = 0 # 隨機決定index的開頭 
    while len(batch_index) <= 77:  # 1個batch裡只有77筆資料
        temp.append(count)
        count += 1
        if len(temp) == batch_size:
            batch_index.append(temp)
            temp = []
        if count == len(train_source):
            count = 0
    
    # 一開始會出現[True , True , True , True , True , True , True , True]
    # 隨著epoch的增長，逐漸開始出現[Faslse , Faslse , Faslse , Faslse , Faslse , Faslse , Faslse , Faslse]
    # 在Decoder端的訓練，一開始t階段的輸入為t-1階段的期望輸出(Teacher Forcing)，到最後逐漸變為t階段的輸入為t-1階段的輸出(Sampling)
    coin_tossing = np.random.choice(a = 2 , 
                                    size = target_max_length , 
                                    replace = True , 
                                    p = [prob , 1 - prob])
    coin_tossing = coin_tossing.astype(bool)
    if alpha * prob < 1  : prob = alpha * prob # p會隨著epoch增加越來越大
    elif alpha * prob > 1: prob = 1.        

    for batch_i in range(0 , 77):
        train_source_batch , train_target_batch =\
        train_source[batch_index[batch_i] , :] , train_target[batch_index[batch_i] , :] 
        
        _ , training_loss , predicting_logits_result =\
        sess.run([train_op, total_loss , predicting_logits] , 
                 eed_dict = {input_data : train_source_batch ,
                             targets : train_target_batch ,
                             from_model_or_target : coin_tossing ,
                             lr: learning_rate})
   
        if batch_i % 30 == 0: # 每隔30個輪查看一下結果
            validation_loss = sess.run(total_loss, 
                                       feed_dict = {input_data : valid_source ,
                                                    targets : valid_target ,
                                                    from_model_or_target : coin_tossing}) 

            print('Epoch : {}/{} \nBatch : {}/{} \nTraining Loss : {:.3f} \nValidation loss: {:.3f} \nstop_early : {} \ncoin_tossing : {}'
                  .format(epoch_i , epochs , 
                          batch_i , len(train_source) // batch_size , 
                          training_loss , validation_loss , 
                          stop_early , coin_tossing))
            
            index = np.random.randint(batch_size)
            print('Source : {}'.format([source_int_to_letter[i] for i in train_source_batch[index]] ))
            print('Target : {}'.format([target_int_to_letter[i] for i in train_target_batch[index]] ))
            print('Predict : {}\n'.format([target_int_to_letter[i] for i in predicting_logits_result[index]] ))
        
    if coin_tossing.sum() == 0:
        stop_early += 1

    if stop_early == 20: # 當coin_tossing全部為False的次數為20時即停止計算
        break        
    
    
# 保存模型
saver = tf.train.Saver()
saver.save(sess , 'trained_model/save_net')
print('Model Trained and Saved')
# Out:
# Epoch : 0/200
# Batch : 0/77
# Training Loss : 3.358
# Validation loss: 3.316
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['t', 'j', 'q', 'r', 'z', '<PAD>', '<PAD>']
# Target : ['j', 'q', 'r', 't', 'z', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['<GO>', '<GO>', 'p', 'p', 'p', 'p', 'p', 'c']
#
# Epoch : 0/200
# Batch : 30/77
# Training Loss : 2.384
# Validation loss: 2.347
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['z', 'g', 'l', 'h', 'w', 'd', '<PAD>']
# Target : ['d', 'g', 'h', 'l', 'w', 'z', '<EOS>', '<PAD>']
# Predict : ['<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 0/200
# Batch : 60/77
# Training Loss : 2.020
# Validation loss: 2.050
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['b', 'h', 'g', 'k', '<PAD>', '<PAD>', '<PAD>']
# Target : ['b', 'g', 'h', 'k', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['b', '<EOS>', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 1/200
# Batch : 0/77
# Training Loss : 1.962
# Validation loss: 1.844
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['d', 'k', 'e', 'x', 'p', 'j', 'g']
# Target : ['d', 'e', 'g', 'j', 'k', 'p', 'x', '<EOS>']
# Predict : ['b', 'b', 'b', 'e', 'j', '<EOS>', '<EOS>', '<EOS>']
#
# Epoch : 1/200
# Batch : 30/77
# Training Loss : 1.669
# Validation loss: 1.649
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['d', 'v', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['d', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['b', '<EOS>', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 1/200
# Batch : 60/77
# Training Loss : 1.488
# Validation loss: 1.514
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['y', 's', 'f', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 's', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['b', 'k', '<EOS>', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 2/200
# Batch : 0/77
# Training Loss : 1.566
# Validation loss: 1.465
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['h', 's', 't', 'm', 'q', 'q', 'c']
# Target : ['c', 'h', 'm', 'q', 'q', 's', 't', '<EOS>']
# Predict : ['a', 'e', 'j', 'n', 'p', 'x', '<EOS>', '<EOS>']
#
# Epoch : 2/200
# Batch : 30/77
# Training Loss : 1.423
# Validation loss: 1.404
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['a', 'b', 'q', 'k', 'q', 'l', 'p']
# Target : ['a', 'b', 'k', 'l', 'p', 'q', 'q', '<EOS>']
# Predict : ['a', 'b', 'j', 'j', 'r', 't', 'y', '<EOS>']
#
# Epoch : 2/200
# Batch : 60/77
# Training Loss : 1.322
# Validation loss: 1.350
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['u', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['u', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['<EOS>', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 3/200
# Batch : 0/77
# Training Loss : 1.408
# Validation loss: 1.310
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['m', 't', 'r', 'n', 'j', 'b', '<PAD>']
# Target : ['b', 'j', 'm', 'n', 'r', 't', '<EOS>', '<PAD>']
# Predict : ['a', 'f', 'j', 'p', 't', 'w', '<EOS>', '<PAD>']
#
# Epoch : 3/200
# Batch : 30/77
# Training Loss : 1.266
# Validation loss: 1.240
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['s', 'w', 'l', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['l', 's', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['j', 'r', '<EOS>', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 3/200
# Batch : 60/77
# Training Loss : 1.132
# Validation loss: 1.178
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['w', 'z', 'p', 'v', 'b', 'w', 'u']
# Target : ['b', 'p', 'u', 'v', 'w', 'w', 'z', '<EOS>']
# Predict : ['h', 'h', 'p', 'v', 'v', 'y', '<EOS>', '<EOS>']
#
# Epoch : 4/200
# Batch : 0/77
# Training Loss : 1.226
# Validation loss: 1.150
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['h', 'v', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['h', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['h', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 4/200
# Batch : 30/77
# Training Loss : 1.102
# Validation loss: 1.089
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['z', 'w', 'o', 'l', 'l', '<PAD>', '<PAD>']
# Target : ['l', 'l', 'o', 'w', 'z', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['h', 'p', 't', 'w', 'z', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 4/200
# Batch : 60/77
# Training Loss : 0.998
# Validation loss: 1.034
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['c', 'h', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['c', 'h', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['c', 'n', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 5/200
# Batch : 0/77
# Training Loss : 1.083
# Validation loss: 1.008
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['o', 'p', 'i', 'v', 'v', 'i', '<PAD>']
# Target : ['i', 'i', 'o', 'p', 'v', 'v', '<EOS>', '<PAD>']
# Predict : ['f', 'l', 'n', 'p', 't', 'w', '<EOS>', '<PAD>']
#
# Epoch : 5/200
# Batch : 30/77
# Training Loss : 0.953
# Validation loss: 0.949
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['d', 'u', 'z', 'f', '<PAD>', '<PAD>', '<PAD>']
# Target : ['d', 'f', 'u', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['a', 'g', 'u', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 5/200
# Batch : 60/77
# Training Loss : 0.872
# Validation loss: 0.905
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['k', 'r', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['k', 'r', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['h', 'r', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 6/200
# Batch : 0/77
# Training Loss : 0.952
# Validation loss: 0.884
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['y', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 6/200
# Batch : 30/77
# Training Loss : 0.843
# Validation loss: 0.842
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['v', 'f', 'p', 'b', 'o', 'n', 'q']
# Target : ['b', 'f', 'n', 'o', 'p', 'q', 'v', '<EOS>']
# Predict : ['b', 'f', 'j', 'q', 'q', 't', 'w', '<EOS>']
#
# Epoch : 6/200
# Batch : 60/77
# Training Loss : 0.775
# Validation loss: 0.806
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['l', 'r', 't', 'x', 'g', 'y', '<PAD>']
# Target : ['g', 'l', 'r', 't', 'x', 'y', '<EOS>', '<PAD>']
# Predict : ['h', 'o', 's', 's', 'x', 'y', '<EOS>', '<PAD>']
#
# Epoch : 7/200
# Batch : 0/77
# Training Loss : 0.852
# Validation loss: 0.792
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['q', 't', 'g', 'p', 'u', '<PAD>', '<PAD>']
# Target : ['g', 'p', 'q', 't', 'u', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['f', 'q', 'q', 't', 'v', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 7/200
# Batch : 30/77
# Training Loss : 0.758
# Validation loss: 0.754
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['w', 'i', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['i', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['p', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 7/200
# Batch : 60/77
# Training Loss : 0.690
# Validation loss: 0.716
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['r', 'y', 'i', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['i', 'r', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['h', 'r', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Epoch : 8/200
# Batch : 0/77
# Training Loss : 0.756
# Validation loss: 0.707
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['p', 'f', 'f', 'p', 'x', '<PAD>', '<PAD>']
# Target : ['f', 'f', 'p', 'p', 'x', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['f', 'f', 'p', 'r', 'w', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 8/200
# Batch : 30/77
# Training Loss : 0.667
# Validation loss: 0.662
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['e', 'p', 's', 'g', 'q', 'v', '<PAD>']
# Target : ['e', 'g', 'p', 'q', 's', 'v', '<EOS>', '<PAD>']
# Predict : ['b', 'f', 'j', 'p', 's', 'v', '<EOS>', '<PAD>']
#
# Epoch : 8/200
# Batch : 60/77
# Training Loss : 0.605
# Validation loss: 0.619
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['z', 'i', 'y', 'o', 'x', 'a', '<PAD>']
# Target : ['a', 'i', 'o', 'x', 'y', 'z', '<EOS>', '<PAD>']
# Predict : ['b', 'k', 'o', 'x', 'y', 'z', '<EOS>', '<PAD>']
#
# Epoch : 9/200
# Batch : 0/77
# Training Loss : 0.663
# Validation loss: 0.604
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['y', 'z', 's', 'c', 'j', 's', 't']
# Target : ['c', 'j', 's', 's', 't', 'y', 'z', '<EOS>']
# Predict : ['c', 'l', 's', 's', 'v', 'y', 'y', '<EOS>']
#
# Epoch : 9/200
# Batch : 30/77
# Training Loss : 0.581
# Validation loss: 0.570
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['q', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['q', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['q', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 9/200
# Batch : 60/77
# Training Loss : 0.524
# Validation loss: 0.537
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['g', 'p', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['g', 'p', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['g', 'r', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 10/200
# Batch : 0/77
# Training Loss : 0.573
# Validation loss: 0.521
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['o', 'f', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 'o', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 'o', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 10/200
# Batch : 30/77
# Training Loss : 0.503
# Validation loss: 0.492
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['i', 'x', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['i', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['i', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 10/200
# Batch : 60/77
# Training Loss : 0.457
# Validation loss: 0.468
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['r', 'y', 'i', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['i', 'r', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['k', 'r', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 11/200
# Batch : 0/77
# Training Loss : 0.498
# Validation loss: 0.454
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['e', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['e', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['e', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 11/200
# Batch : 30/77
# Training Loss : 0.441
# Validation loss: 0.427
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['o', 'c', 'w', 'f', '<PAD>', '<PAD>', '<PAD>']
# Target : ['c', 'f', 'o', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['b', 'f', 'p', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 11/200
# Batch : 60/77
# Training Loss : 0.397
# Validation loss: 0.408
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['b', 't', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['b', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['b', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 12/200
# Batch : 0/77
# Training Loss : 0.433
# Validation loss: 0.398
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['d', 'a', 'v', 'o', 'k', 'o', 'c']
# Target : ['a', 'c', 'd', 'k', 'o', 'o', 'v', '<EOS>']
# Predict : ['a', 'd', 'd', 'h', 'o', 'o', 'v', '<EOS>']
#
# Epoch : 12/200
# Batch : 30/77
# Training Loss : 0.382
# Validation loss: 0.374
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['l', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['l', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['l', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 12/200
# Batch : 60/77
# Training Loss : 0.342
# Validation loss: 0.358
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['p', 'x', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['p', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['p', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 13/200
# Batch : 0/77
# Training Loss : 0.375
# Validation loss: 0.348
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['h', 's', 't', 'm', 'q', 'q', 'c']
# Target : ['c', 'h', 'm', 'q', 'q', 's', 't', '<EOS>']
# Predict : ['f', 'h', 'm', 'q', 'q', 's', 't', '<EOS>']
#
# Epoch : 13/200
# Batch : 30/77
# Training Loss : 0.336
# Validation loss: 0.330
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['w', 'h', 'o', 'g', 'v', 'd', '<PAD>']
# Target : ['d', 'g', 'h', 'o', 'v', 'w', '<EOS>', '<PAD>']
# Predict : ['d', 'g', 'h', 'o', 'w', 'w', '<EOS>', '<PAD>']
#
# Epoch : 13/200
# Batch : 60/77
# Training Loss : 0.300
# Validation loss: 0.318
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['d', 'i', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['d', 'i', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['d', 'i', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 14/200
# Batch : 0/77
# Training Loss : 0.334
# Validation loss: 0.312
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['y', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 14/200
# Batch : 30/77
# Training Loss : 0.296
# Validation loss: 0.300
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['q', 'e', 'j', 'd', '<PAD>', '<PAD>', '<PAD>']
# Target : ['d', 'e', 'j', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['e', 'e', 'j', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 14/200
# Batch : 60/77
# Training Loss : 0.264
# Validation loss: 0.291
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['w', 'z', 'p', 'v', 'b', 'w', 'u']
# Target : ['b', 'p', 'u', 'v', 'w', 'w', 'z', '<EOS>']
# Predict : ['b', 'p', 't', 'v', 'w', 'w', 'z', '<EOS>']
#
# Epoch : 15/200
# Batch : 0/77
# Training Loss : 0.301
# Validation loss: 0.280
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['v', 'q', 'i', 's', 't', 'a', 'i']
# Target : ['a', 'i', 'i', 'q', 's', 't', 'v', '<EOS>']
# Predict : ['a', 'i', 'i', 'q', 's', 't', 'v', '<EOS>']
#
# Epoch : 15/200
# Batch : 30/77
# Training Loss : 0.264
# Validation loss: 0.272
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['m', 'o', 'r', 'i', 'f', '<PAD>', '<PAD>']
# Target : ['f', 'i', 'm', 'o', 'r', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['f', 'i', 'k', 'o', 'r', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 15/200
# Batch : 60/77
# Training Loss : 0.234
# Validation loss: 0.266
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['e', 'c', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['c', 'e', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['c', 'e', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Epoch : 16/200
# Batch : 0/77
# Training Loss : 0.272
# Validation loss: 0.252
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['y', 'b', 'z', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['b', 'y', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['b', 'z', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 16/200
# Batch : 30/77
# Training Loss : 0.237
# Validation loss: 0.246
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['d', 'p', 'i', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['d', 'i', 'p', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['d', 'i', 'p', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 16/200
# Batch : 60/77
# Training Loss : 0.212
# Validation loss: 0.262
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['f', 'o', 'e', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['e', 'f', 'o', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['e', 'f', 'o', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 17/200
# Batch : 0/77
# Training Loss : 0.278
# Validation loss: 0.231
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['b', 'g', 't', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['b', 'g', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['a', 'g', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 17/200
# Batch : 30/77
# Training Loss : 0.218
# Validation loss: 0.233
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['j', 'm', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['j', 'm', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['j', 'm', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 17/200
# Batch : 60/77
# Training Loss : 0.196
# Validation loss: 0.220
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['l', 'n', 'l', 'x', 'b', 'a', '<PAD>']
# Target : ['a', 'b', 'l', 'l', 'n', 'x', '<EOS>', '<PAD>']
# Predict : ['a', 'c', 'l', 'l', 'n', 'x', '<EOS>', '<PAD>']
#
# Epoch : 18/200
# Batch : 0/77
# Training Loss : 0.226
# Validation loss: 0.216
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['j', 'h', 'g', 'b', 'i', '<PAD>', '<PAD>']
# Target : ['b', 'g', 'h', 'i', 'j', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['b', 'g', 'g', 'i', 'j', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 18/200
# Batch : 30/77
# Training Loss : 0.197
# Validation loss: 0.210
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['w', 'r', 'o', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['o', 'r', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['o', 'r', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 18/200
# Batch : 60/77
# Training Loss : 0.175
# Validation loss: 0.206
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['w', 'v', 's', 'm', 'd', '<PAD>', '<PAD>']
# Target : ['d', 'm', 's', 'v', 'w', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['d', 'm', 's', 'v', 'w', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 19/200
# Batch : 0/77
# Training Loss : 0.208
# Validation loss: 0.201
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['j', 'd', 'w', 'y', 'u', 'b', 'e']
# Target : ['b', 'd', 'e', 'j', 'u', 'w', 'y', '<EOS>']
# Predict : ['d', 'd', 'd', 'l', 'u', 'w', 'y', '<EOS>']
#
# Epoch : 19/200
# Batch : 30/77
# Training Loss : 0.178
# Validation loss: 0.193
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['r', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['r', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['r', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 19/200
# Batch : 60/77
# Training Loss : 0.160
# Validation loss: 0.191
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['f', 'j', 'u', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 'j', 'u', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 'j', 'u', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 20/200
# Batch : 0/77
# Training Loss : 0.191
# Validation loss: 0.185
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['s', 'd', 'o', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['d', 'o', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['d', 'o', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 20/200
# Batch : 30/77
# Training Loss : 0.164
# Validation loss: 0.177
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['b', 'w', 'u', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['b', 'u', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['b', 't', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 20/200
# Batch : 60/77
# Training Loss : 0.146
# Validation loss: 0.179
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['b', 'h', 'g', 'k', '<PAD>', '<PAD>', '<PAD>']
# Target : ['b', 'g', 'h', 'k', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['b', 'g', 'h', 'k', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 21/200
# Batch : 0/77
# Training Loss : 0.176
# Validation loss: 0.171
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['w', 'x', 'x', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['w', 'x', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['w', 'x', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 21/200
# Batch : 30/77
# Training Loss : 0.152
# Validation loss: 0.164
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['i', 'h', 'c', 'c', 'x', 'n', '<PAD>']
# Target : ['c', 'c', 'h', 'i', 'n', 'x', '<EOS>', '<PAD>']
# Predict : ['c', 'c', 'h', 'i', 'n', 'y', '<EOS>', '<PAD>']
#
# Epoch : 21/200
# Batch : 60/77
# Training Loss : 0.134
# Validation loss: 0.168
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['f', 'x', 'm', 'p', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 'm', 'p', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 'm', 'p', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 22/200
# Batch : 0/77
# Training Loss : 0.163
# Validation loss: 0.159
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['v', 'w', 'c', 'r', 'g', '<PAD>', '<PAD>']
# Target : ['c', 'g', 'r', 'v', 'w', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['a', 'g', 'r', 'v', 'w', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 22/200
# Batch : 30/77
# Training Loss : 0.141
# Validation loss: 0.152
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['w', 'i', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['i', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['i', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 22/200
# Batch : 60/77
# Training Loss : 0.124
# Validation loss: 0.157
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['s', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['s', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['s', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 23/200
# Batch : 0/77
# Training Loss : 0.152
# Validation loss: 0.147
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['h', 'x', 'p', 'a', 'i', '<PAD>', '<PAD>']
# Target : ['a', 'h', 'i', 'p', 'x', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['a', 'f', 'i', 'p', 'x', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 23/200
# Batch : 30/77
# Training Loss : 0.132
# Validation loss: 0.142
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['b', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['b', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['b', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 23/200
# Batch : 60/77
# Training Loss : 0.115
# Validation loss: 0.147
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['h', 'l', 'z', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['h', 'l', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['h', 'l', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Epoch : 24/200
# Batch : 0/77
# Training Loss : 0.143
# Validation loss: 0.136
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['h', 'v', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['h', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['h', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 24/200
# Batch : 30/77
# Training Loss : 0.123
# Validation loss: 0.133
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['t', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['t', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['t', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 24/200
# Batch : 60/77
# Training Loss : 0.108
# Validation loss: 0.137
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['e', 'y', 'e', 'l', 't', 'p', '<PAD>']
# Target : ['e', 'e', 'l', 'p', 't', 'y', '<EOS>', '<PAD>']
# Predict : ['e', 'e', 'l', 'p', 't', 'y', '<EOS>', '<PAD>']
#
# Epoch : 25/200
# Batch : 0/77
# Training Loss : 0.134
# Validation loss: 0.126
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['y', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 25/200
# Batch : 30/77
# Training Loss : 0.114
# Validation loss: 0.125
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['t', 'w', 'm', 'w', 'u', 'p', 'n']
# Target : ['m', 'n', 'p', 't', 'u', 'w', 'w', '<EOS>']
# Predict : ['m', 'n', 'p', 't', 't', 'w', 'w', '<EOS>']
#
# Epoch : 25/200
# Batch : 60/77
# Training Loss : 0.102
# Validation loss: 0.128
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['k', 'c', 'p', 'p', '<PAD>', '<PAD>', '<PAD>']
# Target : ['c', 'k', 'p', 'p', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['c', 'k', 'p', 'p', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 26/200
# Batch : 0/77
# Training Loss : 0.126
# Validation loss: 0.118
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['p', 'd', 'l', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['d', 'l', 'p', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['d', 'l', 'p', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 26/200
# Batch : 30/77
# Training Loss : 0.107
# Validation loss: 0.116
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['t', 'w', 'm', 'w', 'u', 'p', 'n']
# Target : ['m', 'n', 'p', 't', 'u', 'w', 'w', '<EOS>']
# Predict : ['m', 'n', 'p', 't', 's', 'w', 'w', '<EOS>']
#
# Epoch : 26/200
# Batch : 60/77
# Training Loss : 0.096
# Validation loss: 0.119
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['r', 't', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['r', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['r', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 27/200
# Batch : 0/77
# Training Loss : 0.119
# Validation loss: 0.110
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['g', 'm', 't', 'm', 'g', 'z', '<PAD>']
# Target : ['g', 'g', 'm', 'm', 't', 'z', '<EOS>', '<PAD>']
# Predict : ['g', 'g', 'm', 'm', 'q', 'z', '<EOS>', '<PAD>']
#
# Epoch : 27/200
# Batch : 30/77
# Training Loss : 0.101
# Validation loss: 0.109
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['m', 'q', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['m', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['m', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 27/200
# Batch : 60/77
# Training Loss : 0.088
# Validation loss: 0.112
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['j', 'd', 't', 'i', 's', 'w', 'n']
# Target : ['d', 'i', 'j', 'n', 's', 't', 'w', '<EOS>']
# Predict : ['d', 'i', 'j', 'n', 's', 't', 'w', '<EOS>']
#
# Epoch : 28/200
# Batch : 0/77
# Training Loss : 0.109
# Validation loss: 0.105
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['o', 'j', 'w', 'b', '<PAD>', '<PAD>', '<PAD>']
# Target : ['b', 'j', 'o', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['b', 'j', 'o', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 28/200
# Batch : 30/77
# Training Loss : 0.095
# Validation loss: 0.105
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['l', 'g', 'w', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['g', 'l', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['g', 'l', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 28/200
# Batch : 60/77
# Training Loss : 0.080
# Validation loss: 0.103
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['s', 'n', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['n', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['n', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 29/200
# Batch : 0/77
# Training Loss : 0.101
# Validation loss: 0.099
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['o', 'j', 'w', 'b', '<PAD>', '<PAD>', '<PAD>']
# Target : ['b', 'j', 'o', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['b', 'j', 'o', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 29/200
# Batch : 30/77
# Training Loss : 0.087
# Validation loss: 0.100
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['y', 'q', 'w', 'a', '<PAD>', '<PAD>', '<PAD>']
# Target : ['a', 'q', 'w', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['a', 'q', 'w', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 29/200
# Batch : 60/77
# Training Loss : 0.075
# Validation loss: 0.098
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['x', 'f', 'g', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 'g', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 'g', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 30/200
# Batch : 0/77
# Training Loss : 0.094
# Validation loss: 0.092
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['o', 'g', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['g', 'o', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['g', 'o', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 30/200
# Batch : 30/77
# Training Loss : 0.082
# Validation loss: 0.095
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['o', 't', 'a', 'i', 'h', 'i', 'd']
# Target : ['a', 'd', 'h', 'i', 'i', 'o', 't', '<EOS>']
# Predict : ['a', 'd', 'g', 'i', 'i', 'o', 't', '<EOS>']
#
# Epoch : 30/200
# Batch : 60/77
# Training Loss : 0.069
# Validation loss: 0.093
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['w', 'l', 'u', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['l', 'u', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['l', 'u', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 31/200
# Batch : 0/77
# Training Loss : 0.091
# Validation loss: 0.087
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['r', 'z', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['r', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['r', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 31/200
# Batch : 30/77
# Training Loss : 0.077
# Validation loss: 0.091
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['d', 'p', 'i', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['d', 'i', 'p', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['d', 'i', 'p', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 31/200
# Batch : 60/77
# Training Loss : 0.065
# Validation loss: 0.086
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['t', 'e', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['e', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['e', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Epoch : 32/200
# Batch : 0/77
# Training Loss : 0.085
# Validation loss: 0.086
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['p', 't', 'g', 'f', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 'g', 'p', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 'g', 'p', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 32/200
# Batch : 30/77
# Training Loss : 0.075
# Validation loss: 0.092
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['d', 'u', 'z', 'f', '<PAD>', '<PAD>', '<PAD>']
# Target : ['d', 'f', 'u', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['d', 'f', 'u', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 32/200
# Batch : 60/77
# Training Loss : 0.061
# Validation loss: 0.082
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['p', 'd', 'c', 'g', 'g', '<PAD>', '<PAD>']
# Target : ['c', 'd', 'g', 'g', 'p', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['c', 'd', 'g', 'g', 'p', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 33/200
# Batch : 0/77
# Training Loss : 0.076
# Validation loss: 0.083
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['e', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['e', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['e', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 33/200
# Batch : 30/77
# Training Loss : 0.073
# Validation loss: 0.082
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['o', 'c', 'w', 'f', '<PAD>', '<PAD>', '<PAD>']
# Target : ['c', 'f', 'o', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['c', 'f', 'o', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 33/200
# Batch : 60/77
# Training Loss : 0.059
# Validation loss: 0.078
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['a', 'y', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['a', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['a', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 34/200
# Batch : 0/77
# Training Loss : 0.070
# Validation loss: 0.078
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['y', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 34/200
# Batch : 30/77
# Training Loss : 0.063
# Validation loss: 0.081
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['l', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['l', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['l', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 34/200
# Batch : 60/77
# Training Loss : 0.055
# Validation loss: 0.077
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['w', 'z', 'p', 'v', 'b', 'w', 'u']
# Target : ['b', 'p', 'u', 'v', 'w', 'w', 'z', '<EOS>']
# Predict : ['b', 'p', 'u', 'v', 'w', 'w', 'z', '<EOS>']
#
# Epoch : 35/200
# Batch : 0/77
# Training Loss : 0.067
# Validation loss: 0.075
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['r', 'r', 'y', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['r', 'r', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['r', 'r', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 35/200
# Batch : 30/77
# Training Loss : 0.059
# Validation loss: 0.073
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['o', 't', 'a', 'i', 'h', 'i', 'd']
# Target : ['a', 'd', 'h', 'i', 'i', 'o', 't', '<EOS>']
# Predict : ['a', 'd', 'h', 'i', 'i', 'o', 't', '<EOS>']
#
# Epoch : 35/200
# Batch : 60/77
# Training Loss : 0.052
# Validation loss: 0.075
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['f', 'i', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 'i', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 'i', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 36/200
# Batch : 0/77
# Training Loss : 0.063
# Validation loss: 0.073
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['i', 'y', 'q', 'w', 'k', '<PAD>', '<PAD>']
# Target : ['i', 'k', 'q', 'w', 'y', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['i', 'k', 'q', 'w', 'y', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 36/200
# Batch : 30/77
# Training Loss : 0.057
# Validation loss: 0.071
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['d', 'r', 'y', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['d', 'r', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['d', 'r', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 36/200
# Batch : 60/77
# Training Loss : 0.049
# Validation loss: 0.071
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['s', 't', 'x', 'i', '<PAD>', '<PAD>', '<PAD>']
# Target : ['i', 's', 't', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['i', 's', 't', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 37/200
# Batch : 0/77
# Training Loss : 0.061
# Validation loss: 0.074
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['q', 'v', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['q', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['q', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 37/200
# Batch : 30/77
# Training Loss : 0.055
# Validation loss: 0.067
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['o', 't', 'a', 'i', 'h', 'i', 'd']
# Target : ['a', 'd', 'h', 'i', 'i', 'o', 't', '<EOS>']
# Predict : ['a', 'd', 'h', 'i', 'i', 'o', 't', '<EOS>']
#
# Epoch : 37/200
# Batch : 60/77
# Training Loss : 0.047
# Validation loss: 0.065
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['y', 'v', 'b', 'z', '<PAD>', '<PAD>', '<PAD>']
# Target : ['b', 'v', 'y', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['b', 'v', 'y', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 38/200
# Batch : 0/77
# Training Loss : 0.057
# Validation loss: 0.074
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['p', 'r', 'v', 's', 'y', '<PAD>', '<PAD>']
# Target : ['p', 'r', 's', 'v', 'y', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['p', 'r', 's', 'v', 'y', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 38/200
# Batch : 30/77
# Training Loss : 0.052
# Validation loss: 0.065
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['l', 'v', 'u', 'e', 'v', 'j', 'l']
# Target : ['e', 'j', 'l', 'l', 'u', 'v', 'v', '<EOS>']
# Predict : ['e', 'l', 'l', 'l', 'u', 'v', 'v', '<EOS>']
#
# Epoch : 38/200
# Batch : 60/77
# Training Loss : 0.055
# Validation loss: 0.061
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['m', 'u', 'r', 'm', 'j', 'c', 'g']
# Target : ['c', 'g', 'j', 'm', 'm', 'r', 'u', '<EOS>']
# Predict : ['a', 'g', 'j', 'm', 'm', 'r', 'u', '<EOS>']
#
# Epoch : 39/200
# Batch : 0/77
# Training Loss : 0.052
# Validation loss: 0.069
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['i', 'y', 'q', 'w', 'k', '<PAD>', '<PAD>']
# Target : ['i', 'k', 'q', 'w', 'y', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['i', 'k', 'q', 'w', 'y', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 39/200
# Batch : 30/77
# Training Loss : 0.048
# Validation loss: 0.065
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['b', 'w', 't', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['b', 't', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['b', 't', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 39/200
# Batch : 60/77
# Training Loss : 0.045
# Validation loss: 0.061
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['t', 'w', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['t', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['t', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Epoch : 40/200
# Batch : 0/77
# Training Loss : 0.054
# Validation loss: 0.059
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['k', 'a', 'l', 'e', 'y', 'p', '<PAD>']
# Target : ['a', 'e', 'k', 'l', 'p', 'y', '<EOS>', '<PAD>']
# Predict : ['a', 'e', 'k', 'l', 'p', 'y', '<EOS>', '<PAD>']
#
# Epoch : 40/200
# Batch : 30/77
# Training Loss : 0.046
# Validation loss: 0.059
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['o', 'o', 'n', 's', '<PAD>', '<PAD>', '<PAD>']
# Target : ['n', 'o', 'o', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['n', 'o', 'o', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 40/200
# Batch : 60/77
# Training Loss : 0.047
# Validation loss: 0.060
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['l', 'v', 'a', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['a', 'l', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['a', 'l', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 41/200
# Batch : 0/77
# Training Loss : 0.047
# Validation loss: 0.057
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['r', 'z', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['r', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['r', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 41/200
# Batch : 30/77
# Training Loss : 0.045
# Validation loss: 0.058
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['l', 'g', 'w', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['g', 'l', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['g', 'l', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 41/200
# Batch : 60/77
# Training Loss : 0.041
# Validation loss: 0.053
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['z', 'm', 'j', 'k', 'p', 'c', '<PAD>']
# Target : ['c', 'j', 'k', 'm', 'p', 'z', '<EOS>', '<PAD>']
# Predict : ['c', 'k', 'k', 'm', 'p', 'z', '<EOS>', '<PAD>']
#
# Epoch : 42/200
# Batch : 0/77
# Training Loss : 0.048
# Validation loss: 0.062
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['t', 'e', 'z', 't', 'q', '<PAD>', '<PAD>']
# Target : ['e', 'q', 't', 't', 'z', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['e', 'q', 't', 't', 'z', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 42/200
# Batch : 30/77
# Training Loss : 0.042
# Validation loss: 0.052
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['d', 'u', 'z', 'f', '<PAD>', '<PAD>', '<PAD>']
# Target : ['d', 'f', 'u', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['d', 'f', 'u', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 42/200
# Batch : 60/77
# Training Loss : 0.040
# Validation loss: 0.050
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['h', 'l', 'z', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['h', 'l', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['h', 'l', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 43/200
# Batch : 0/77
# Training Loss : 0.043
# Validation loss: 0.087
# stop_early : 0
# coin_tossing : [ True  True  True False  True  True  True  True]
# Source : ['s', 'd', 'v', 'm', 'f', '<PAD>', '<PAD>']
# Target : ['d', 'f', 'm', 's', 'v', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['d', 'f', 'm', 's', 'v', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 43/200
# Batch : 30/77
# Training Loss : 0.056
# Validation loss: 0.115
# stop_early : 0
# coin_tossing : [ True  True  True False  True  True  True  True]
# Source : ['a', 'i', 'o', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['a', 'i', 'o', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['a', 'i', 'o', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 43/200
# Batch : 60/77
# Training Loss : 0.053
# Validation loss: 0.105
# stop_early : 0
# coin_tossing : [ True  True  True False  True  True  True  True]
# Source : ['v', 'o', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['o', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['o', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 44/200
# Batch : 0/77
# Training Loss : 0.120
# Validation loss: 0.141
# stop_early : 0
# coin_tossing : [ True False  True  True  True  True  True  True]
# Source : ['q', 'w', 't', 'p', 'g', 'q', '<PAD>']
# Target : ['g', 'p', 'q', 'q', 't', 'w', '<EOS>', '<PAD>']
# Predict : ['f', 'l', 'q', 'u', 'v', 'y', '<EOS>', '<PAD>']
#
# Epoch : 44/200
# Batch : 30/77
# Training Loss : 0.056
# Validation loss: 0.109
# stop_early : 0
# coin_tossing : [ True False  True  True  True  True  True  True]
# Source : ['m', 'q', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['m', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['m', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 44/200
# Batch : 60/77
# Training Loss : 0.094
# Validation loss: 0.156
# stop_early : 0
# coin_tossing : [ True False  True  True  True  True  True  True]
# Source : ['g', 'g', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['g', 'g', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['g', 'g', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 45/200
# Batch : 0/77
# Training Loss : 0.054
# Validation loss: 0.070
# stop_early : 0
# coin_tossing : [ True  True  True  True  True  True  True  True]
# Source : ['w', 'r', 'q', 'd', '<PAD>', '<PAD>', '<PAD>']
# Target : ['d', 'q', 'r', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['d', 'q', 'r', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 45/200
# Batch : 30/77
# Training Loss : 0.041
# Validation loss: 0.051
# stop_early : 0
# ...
# Target : ['p', 't', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['p', 't', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 100/200
# Batch : 0/77
# Training Loss : 0.013
# Validation loss: 0.038
# stop_early : 5
# coin_tossing : [False False False False False False False False]
# Source : ['p', 'd', 'l', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['d', 'l', 'p', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['d', 'l', 'p', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 100/200
# Batch : 30/77
# Training Loss : 0.019
# Validation loss: 0.047
# stop_early : 5
# coin_tossing : [False False False False False False False False]
# Source : ['o', 'y', 'd', 'y', '<PAD>', '<PAD>', '<PAD>']
# Target : ['d', 'o', 'y', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['d', 'o', 'y', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 100/200
# Batch : 60/77
# Training Loss : 0.026
# Validation loss: 0.034
# stop_early : 5
# coin_tossing : [False False False False False False False False]
# Source : ['h', 'n', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['h', 'n', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['h', 'n', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 101/200
# Batch : 0/77
# Training Loss : 0.011
# Validation loss: 0.048
# stop_early : 6
# coin_tossing : [False False False False False False False False]
# Source : ['b', 'w', 'b', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['b', 'b', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['b', 'b', 'w', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 101/200
# Batch : 30/77
# Training Loss : 0.022
# Validation loss: 0.038
# stop_early : 6
# coin_tossing : [False False False False False False False False]
# Source : ['z', 'a', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['a', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['a', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 101/200
# Batch : 60/77
# Training Loss : 0.008
# Validation loss: 0.044
# stop_early : 6
# coin_tossing : [False False False False False False False False]
# Source : ['e', 'c', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['c', 'e', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['c', 'e', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 102/200
# Batch : 0/77
# Training Loss : 0.008
# Validation loss: 0.032
# stop_early : 7
# coin_tossing : [False False False False False False False False]
# Source : ['s', 'l', 'a', 'g', '<PAD>', '<PAD>', '<PAD>']
# Target : ['a', 'g', 'l', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['a', 'g', 'l', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 102/200
# Batch : 30/77
# Training Loss : 0.019
# Validation loss: 0.034
# stop_early : 7
# coin_tossing : [False False False False False False False False]
# Source : ['l', 'v', 'u', 'e', 'v', 'j', 'l']
# Target : ['e', 'j', 'l', 'l', 'u', 'v', 'v', '<EOS>']
# Predict : ['e', 'l', 'l', 'l', 't', 'v', 'v', '<EOS>']
#
# Epoch : 102/200
# Batch : 60/77
# Training Loss : 0.008
# Validation loss: 0.036
# stop_early : 7
# coin_tossing : [False False False False False False False False]
# Source : ['o', 'o', 'j', 'w', 't', 'm', 'b']
# Target : ['b', 'j', 'm', 'o', 'o', 't', 'w', '<EOS>']
# Predict : ['b', 'j', 'm', 'o', 'o', 't', 'w', '<EOS>']
#
# Epoch : 103/200
# Batch : 0/77
# Training Loss : 0.007
# Validation loss: 0.035
# stop_early : 8
# coin_tossing : [False False False False False False False False]
# Source : ['e', 'z', 'x', 'r', '<PAD>', '<PAD>', '<PAD>']
# Target : ['e', 'r', 'x', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['e', 'r', 'x', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 103/200
# Batch : 30/77
# Training Loss : 0.021
# Validation loss: 0.036
# stop_early : 8
# coin_tossing : [False False False False False False False False]
# Source : ['z', 'g', 'd', 'y', 'q', '<PAD>', '<PAD>']
# Target : ['d', 'g', 'q', 'y', 'z', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['d', 'g', 'q', 'y', 'z', '<EOS>', '<PAD>', '<PAD>']
# Epoch : 103/200
# Batch : 60/77
# Training Loss : 0.007
# Validation loss: 0.042
# stop_early : 8
# coin_tossing : [False False False False False False False False]
# Source : ['a', 'y', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['a', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['a', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 104/200
# Batch : 0/77
# Training Loss : 0.006
# Validation loss: 0.048
# stop_early : 9
# coin_tossing : [False False False False False False False False]
# Source : ['s', 'b', 'g', 'e', 'e', 'f', 'f']
# Target : ['b', 'e', 'e', 'f', 'f', 'g', 's', '<EOS>']
# Predict : ['b', 'e', 'e', 'f', 'f', 'g', 's', '<EOS>']
#
# Epoch : 104/200
# Batch : 30/77
# Training Loss : 0.007
# Validation loss: 0.032
# stop_early : 9
# coin_tossing : [False False False False False False False False]
# Source : ['d', 'v', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['d', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['d', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 104/200
# Batch : 60/77
# Training Loss : 0.007
# Validation loss: 0.043
# stop_early : 9
# coin_tossing : [False False False False False False False False]
# Source : ['s', 'i', 'r', 'e', 'n', 'w', 'g']
# Target : ['e', 'g', 'i', 'n', 'r', 's', 'w', '<EOS>']
# Predict : ['e', 'g', 'i', 'n', 'r', 's', 'w', '<EOS>']
#
# Epoch : 105/200
# Batch : 0/77
# Training Loss : 0.005
# Validation loss: 0.048
# stop_early : 10
# coin_tossing : [False False False False False False False False]
# Source : ['w', 'x', 'x', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['w', 'x', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['w', 'x', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 105/200
# Batch : 30/77
# Training Loss : 0.007
# Validation loss: 0.031
# stop_early : 10
# coin_tossing : [False False False False False False False False]
# Source : ['t', 'm', 't', 'l', 'v', 'e', 'j']
# Target : ['e', 'j', 'l', 'm', 't', 't', 'v', '<EOS>']
# Predict : ['e', 'j', 'l', 'm', 't', 't', 'v', '<EOS>']
#
# Epoch : 105/200
# Batch : 60/77
# Training Loss : 0.006
# Validation loss: 0.043
# stop_early : 10
# coin_tossing : [False False False False False False False False]
# Source : ['x', 'o', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['o', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['o', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 106/200
# Batch : 0/77
# Training Loss : 0.005
# Validation loss: 0.043
# stop_early : 11
# coin_tossing : [False False False False False False False False]
# Source : ['r', 'f', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 'r', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 'r', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 106/200
# Batch : 30/77
# Training Loss : 0.007
# Validation loss: 0.031
# stop_early : 11
# coin_tossing : [False False False False False False False False]
# Source : ['q', 'y', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['q', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['q', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 106/200
# Batch : 60/77
# Training Loss : 0.005
# Validation loss: 0.041
# stop_early : 11
# coin_tossing : [False False False False False False False False]
# Source : ['u', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['u', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['u', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 107/200
# Batch : 0/77
# Training Loss : 0.004
# Validation loss: 0.040
# stop_early : 12
# coin_tossing : [False False False False False False False False]
# Source : ['h', 'v', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['h', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['h', 'v', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 107/200
# Batch : 30/77
# Training Loss : 0.006
# Validation loss: 0.032
# stop_early : 12
# coin_tossing : [False False False False False False False False]
# Source : ['c', 's', 'u', 'p', 'p', '<PAD>', '<PAD>']
# Target : ['c', 'p', 'p', 's', 'u', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['c', 'p', 'p', 's', 'u', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 107/200
# Batch : 60/77
# Training Loss : 0.005
# Validation loss: 0.042
# stop_early : 12
# coin_tossing : [False False False False False False False False]
# Source : ['h', 'z', 'x', 'q', 'a', 'n', '<PAD>']
# Target : ['a', 'h', 'n', 'q', 'x', 'z', '<EOS>', '<PAD>']
# Predict : ['a', 'h', 'n', 'q', 'x', 'z', '<EOS>', '<PAD>']
#
# Epoch : 108/200
# Batch : 0/77
# Training Loss : 0.004
# Validation loss: 0.041
# stop_early : 13
# coin_tossing : [False False False False False False False False]
# Source : ['s', 'l', 'a', 'g', '<PAD>', '<PAD>', '<PAD>']
# Target : ['a', 'g', 'l', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['a', 'g', 'l', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 108/200
# Batch : 30/77
# Training Loss : 0.005
# Validation loss: 0.035
# stop_early : 13
# coin_tossing : [False False False False False False False False]
# Source : ['q', 'q', 'i', 'r', 'f', 'n', 'q']
# Target : ['f', 'i', 'n', 'q', 'q', 'q', 'r', '<EOS>']
# Predict : ['f', 'i', 'n', 'q', 'q', 'q', 'r', '<EOS>']
#
# Epoch : 108/200
# Batch : 60/77
# Training Loss : 0.004
# Validation loss: 0.043
# stop_early : 13
# coin_tossing : [False False False False False False False False]
# Source : ['z', 'w', 'o', 'e', 'q', 'o', '<PAD>']
# Target : ['e', 'o', 'o', 'q', 'w', 'z', '<EOS>', '<PAD>']
# Predict : ['e', 'o', 'o', 'q', 'w', 'z', '<EOS>', '<PAD>']
#
# Epoch : 109/200
# Batch : 0/77
# Training Loss : 0.004
# Validation loss: 0.041
# stop_early : 14
# coin_tossing : [False False False False False False False False]
# Source : ['q', 't', 'g', 'p', 'u', '<PAD>', '<PAD>']
# Target : ['g', 'p', 'q', 't', 'u', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['g', 'p', 'q', 't', 'u', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 109/200
# Batch : 30/77
# Training Loss : 0.005
# Validation loss: 0.037
# stop_early : 14
# coin_tossing : [False False False False False False False False]
# Source : ['m', 'q', 'm', 'w', 'u', 'l', '<PAD>']
# Target : ['l', 'm', 'm', 'q', 'u', 'w', '<EOS>', '<PAD>']
# Predict : ['l', 'm', 'm', 'q', 'u', 'w', '<EOS>', '<PAD>']
#
# Epoch : 109/200
# Batch : 60/77
# Training Loss : 0.004
# Validation loss: 0.043
# stop_early : 14
# coin_tossing : [False False False False False False False False]
# Source : ['f', 'x', 'm', 'p', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 'm', 'p', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 'm', 'p', 'x', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 110/200
# Batch : 0/77
# Training Loss : 0.004
# Validation loss: 0.032
# stop_early : 15
# coin_tossing : [False False False False False False False False]
# Source : ['t', 'j', 'e', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['e', 'j', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['e', 'j', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 110/200
# Batch : 30/77
# Training Loss : 0.005
# Validation loss: 0.036
# stop_early : 15
# coin_tossing : [False False False False False False False False]
# Source : ['s', 'b', 'g', 'x', 'y', 'i', 'p']
# Target : ['b', 'g', 'i', 'p', 's', 'x', 'y', '<EOS>']
# Predict : ['b', 'g', 'i', 'p', 's', 'x', 'y', '<EOS>']
#
# Epoch : 110/200
# Batch : 60/77
# Training Loss : 0.004
# Validation loss: 0.043
# stop_early : 15
# coin_tossing : [False False False False False False False False]
# Source : ['t', 'c', 'i', 'h', '<PAD>', '<PAD>', '<PAD>']
# Target : ['c', 'h', 'i', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['c', 'h', 'i', 't', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 111/200
# Batch : 0/77
# Training Loss : 0.003
# Validation loss: 0.033
# stop_early : 16
# coin_tossing : [False False False False False False False False]
# Source : ['t', 'k', 'u', 'c', 'h', 'l', 'z']
# Target : ['c', 'h', 'k', 'l', 't', 'u', 'z', '<EOS>']
# Predict : ['c', 'h', 'k', 'l', 't', 'u', 'z', '<EOS>']
#
# Epoch : 111/200
# Batch : 30/77
# Training Loss : 0.004
# Validation loss: 0.037
# stop_early : 16
# coin_tossing : [False False False False False False False False]
# Source : ['q', 'i', 'c', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['c', 'i', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['c', 'i', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Epoch : 111/200
# Batch : 60/77
# Training Loss : 0.003
# Validation loss: 0.043
# stop_early : 16
# coin_tossing : [False False False False False False False False]
# Source : ['e', 'a', 'z', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['a', 'e', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['a', 'e', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 112/200
# Batch : 0/77
# Training Loss : 0.003
# Validation loss: 0.036
# stop_early : 17
# coin_tossing : [False False False False False False False False]
# Source : ['d', 'a', 'v', 'o', 'k', 'o', 'c']
# Target : ['a', 'c', 'd', 'k', 'o', 'o', 'v', '<EOS>']
# Predict : ['a', 'c', 'd', 'k', 'o', 'o', 'v', '<EOS>']
#
# Epoch : 112/200
# Batch : 30/77
# Training Loss : 0.004
# Validation loss: 0.038
# stop_early : 17
# coin_tossing : [False False False False False False False False]
# Source : ['q', 'i', 'c', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['c', 'i', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['c', 'i', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 112/200
# Batch : 60/77
# Training Loss : 0.003
# Validation loss: 0.044
# stop_early : 17
# coin_tossing : [False False False False False False False False]
# Source : ['c', 'm', 'u', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['c', 'm', 'u', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['c', 'm', 'u', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 113/200
# Batch : 0/77
# Training Loss : 0.003
# Validation loss: 0.035
# stop_early : 18
# coin_tossing : [False False False False False False False False]
# Source : ['g', 'z', 'm', 'h', 'n', '<PAD>', '<PAD>']
# Target : ['g', 'h', 'm', 'n', 'z', '<EOS>', '<PAD>', '<PAD>']
# Predict : ['g', 'h', 'm', 'n', 'z', '<EOS>', '<PAD>', '<PAD>']
#
# Epoch : 113/200
# Batch : 30/77
# Training Loss : 0.004
# Validation loss: 0.038
# stop_early : 18
# coin_tossing : [False False False False False False False False]
# Source : ['v', 'j', 'e', 'z', '<PAD>', '<PAD>', '<PAD>']
# Target : ['e', 'j', 'v', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['e', 'j', 'v', 'z', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 113/200
# Batch : 60/77
# Training Loss : 0.003
# Validation loss: 0.044
# stop_early : 18
# coin_tossing : [False False False False False False False False]
# Source : ['s', 'n', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['n', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['n', 's', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 114/200
# Batch : 0/77
# Training Loss : 0.003
# Validation loss: 0.036
# stop_early : 19
# coin_tossing : [False False False False False False False False]
# Source : ['q', 'm', 'h', 'e', '<PAD>', '<PAD>', '<PAD>']
# Target : ['e', 'h', 'm', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['e', 'h', 'm', 'q', '<EOS>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 114/200
# Batch : 30/77
# Training Loss : 0.004
# Validation loss: 0.038
# stop_early : 19
# coin_tossing : [False False False False False False False False]
# Source : ['i', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['i', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['i', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Epoch : 114/200
# Batch : 60/77
# Training Loss : 0.003
# Validation loss: 0.034
# stop_early : 19
# coin_tossing : [False False False False False False False False]
# Source : ['y', 's', 'f', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Target : ['f', 's', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# Predict : ['f', 's', 'y', '<EOS>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
#
# Model Trained and Saved

# %% [markdown]
# ## Testing

# %%
import os    
sess = tf.Session()
new_saver = tf.train.import_meta_graph(os.path.join('trained_model/save_net.meta'))
new_saver.restore(sess, tf.train.latest_checkpoint(os.path.join('trained_model')))

graph = tf.get_default_graph()
input_data = graph.get_tensor_by_name('inputs:0')
targets = graph.get_tensor_by_name('targets:0')
predicting_logits = graph.get_tensor_by_name('predictions:0')
from_model_or_target = graph.get_tensor_by_name('on_train:0')

input_word = 'common'

test_source = [] 
for letter in input_word:
    if letter not in source_letter_to_int.keys():
        test_source.append(source_letter_to_int['<UNK>'])
    else:
        test_source.append(source_letter_to_int[letter])
        
# 輸入的句子的長度是固定source_max_length，所以補source_letter_to_int['<PAD>']到長度為source_max_length
while len(test_source) < source_max_length:
    test_source.append(source_letter_to_int['<PAD>'])
test_source = [test_source] * batch_size   
        
# test_target輸入的值可以隨便選，只要長度為target_max_length即可    
test_target = [0 for _ in range(0 , target_max_length)] 
test_target = [test_target] * batch_size

test_source = np.array(test_source)
test_target = np.array(test_target)
answer = sess.run(predicting_logits , feed_dict = {input_data : test_source ,
                                                   targets : test_target ,
                                                   from_model_or_target : coin_tossing})

answer = answer[0 , :]
answer_to_letter = []
for num in answer:
    answer_to_letter.append(target_int_to_letter[num])
print(answer_to_letter)
# Out:
# INFO:tensorflow:Restoring parameters from trained_model\save_net
# ['c', 'm', 'm', 'n', 'o', 'o', '<EOS>', '<PAD>']
